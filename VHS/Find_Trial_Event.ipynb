# %%
# %%
import os
from pathlib import Path
import json
import numpy as np
import pandas as pd
import mne

PROJECT_BASE = '/home/jaizor/jaizor/xtra'

class EventToTrialMapper:
    """
    🔥 FINAL VERSION: Maps events to trials using stim channels extracted directly from RAW .fif.
    - NO intermediate file saving.
    - Outputs ONE CSV per subject (optionally saved).
    - Uses rising edge detection on '1a'-'6a' stim channels.
    """

    def __init__(self, project_base, subject='sub-06', save_output=False):
        self.project_base = Path(project_base)
        self.subject = subject
        self.save_output = save_output  # Only save final CSV if True

        # Output dir for final CSV (if saving)
        self.output_dir = self.project_base / "derivatives" / "features" / self.subject
        if self.save_output:
            self.output_dir.mkdir(parents=True, exist_ok=True)

    def detect_rising_edges(self, data, sfreq):
        """
        Detect rising edges (0 → 1) in binary stim channel.
        Returns times in seconds of detected onsets.
        """
        binary = (data > 0.5).astype(int)
        diff = np.diff(binary)
        onset_indices = np.where(diff == 1)[0] + 1  # +1 because diff shifts left
        onset_times = onset_indices / sfreq
        return onset_times

    def extract_pacing_onsets_from_raw(self, raw):
        """
        Extract pacing trigger onsets ('1a'-'6a') directly from raw stim channels.
        Returns DataFrame: ['channel', 'eeg_time_s']
        """
        sfreq = raw.info['sfreq']
        pacing_channels = ['1a', '2a', '3a', '4a', '5a', '6a']
        all_onsets = []

        for ch_name in pacing_channels:
            if ch_name not in raw.ch_names:
                print(f"⚠️  Stim channel '{ch_name}' not found in {self.subject}")
                continue

            data = raw.get_data(picks=[ch_name])[0]
            onset_times = self.detect_rising_edges(data, sfreq)

            for t in onset_times:
                all_onsets.append({'channel': ch_name, 'eeg_time_s': t})

        if not all_onsets:
            raise ValueError(f"❌ No pacing triggers (1a-6a) found in raw data for {self.subject}")

        return pd.DataFrame(all_onsets)

    def define_trials_from_pacing_onsets(self, pacing_onsets_df, trial_gap_threshold_s=2.5, extension_duration_s=4.3):
        """
        Define trials from pacing onsets.
        Returns DataFrame: ['trial_number', 'start_time', 'end_time', 'end_time_extended', 'duration_s', 'subject_id']
        """
        if pacing_onsets_df.empty:
            return pd.DataFrame()

        df = pacing_onsets_df.sort_values('eeg_time_s').reset_index(drop=True)
        times = df['eeg_time_s'].values
        intervals = np.diff(times)
        gap_indices = np.where(intervals > trial_gap_threshold_s)[0]

        boundaries = []
        start_idx = 0
        for gap_idx in gap_indices:
            boundaries.append((start_idx, gap_idx))
            start_idx = gap_idx + 1
        boundaries.append((start_idx, len(df) - 1))

        trials = []
        for start_idx, end_idx in boundaries:
            block = df.iloc[start_idx:end_idx + 1]
            first_1a = block[block['channel'] == '1a']['eeg_time_s'].min()
            last_6a = block[block['channel'] == '6a']['eeg_time_s'].max()

            if pd.notna(first_1a) and pd.notna(last_6a) and last_6a > first_1a:
                trials.append({
                    'trial_number': len(trials) + 1,
                    'start_time': first_1a,
                    'end_time': last_6a,
                    'end_time_extended': last_6a + extension_duration_s,
                    'duration_s': last_6a - first_1a,
                    'subject_id': self.subject
                })

        return pd.DataFrame(trials)

    def load_binary_events(self):
        """
        Load binary events (behavioral/condition events) from .fif + .json.
        Returns DataFrame: ['eeg_time_s', 'event_id', 'condition']
        """
        events_file = self.project_base / "derivatives" / "eeg" / self.subject / "bima_DBSOFF" / f"{self.subject}_events_mne_binary-eve.fif"
        event_id_file = self.project_base / "derivatives" / "eeg" / self.subject / "bima_DBSOFF" / f"{self.subject}_event_id_binary.json"

        if not (events_file.exists() and event_id_file.exists()):
            raise FileNotFoundError(f"❌ Binary event files not found for {self.subject}")

        events = mne.read_events(str(events_file), verbose=False)
        with open(event_id_file, 'r') as f:
            event_id = json.load(f)

        sfreq = 500.0  # You can auto-detect this from raw if needed
        event_times = events[:, 0] / sfreq
        id_to_condition = {v: k for k, v in event_id.items()}
        conditions = [id_to_condition.get(e_id, "Unknown") for e_id in events[:, 2]]

        return pd.DataFrame({
            'eeg_time_s': event_times,
            'event_id': events[:, 2],
            'condition': conditions
        })

    def assign_events_to_trials(self, events_df, trials_df):
        """
        Assign each event to a trial based on time.
        Adds 'trial_number' column.
        """
        def find_trial(t):
            for _, trial in trials_df.iterrows():
                if trial['start_time'] <= t < trial['end_time_extended']:
                    return trial['trial_number']
            return -1

        events_df['trial_number'] = events_df['eeg_time_s'].apply(find_trial)
        return events_df[events_df['trial_number'] != -1].copy()

    def add_stim_channel_info(self, events_df, pacing_onsets_df):
        """
        Add 'stim_channel' column: last pacing trigger (1a-6a) before each event.
        """
        if events_df.empty or pacing_onsets_df.empty:
            return events_df

        pacing_sorted = pacing_onsets_df.sort_values('eeg_time_s').reset_index(drop=True)

        def get_last_stim(t):
            valid = pacing_sorted[pacing_sorted['eeg_time_s'] <= t]
            return valid.iloc[-1]['channel'] if not valid.empty else "unknown"

        events_df['stim_channel'] = events_df['eeg_time_s'].apply(get_last_stim)
        return events_df

    def run(self):
        """
        🔥 MAIN ENTRY POINT — returns final DataFrame (and optionally saves it).
        """
        print(f"\n🚀 Processing {self.subject} — extracting stim channels from RAW, defining trials, mapping events...")

        # --- 1. Load RAW EEG file ---
        raw_file = self.project_base / "derivatives" / "eeg" / self.subject / "bima_DBSOFF" / f"{self.subject}_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif"
        if not raw_file.exists():
            raise FileNotFoundError(f"❌ RAW file not found: {raw_file}")

        raw = mne.io.read_raw_fif(str(raw_file), preload=True)

        # --- 2. Extract pacing onsets from stim channels ---
        pacing_onsets_df = self.extract_pacing_onsets_from_raw(raw)
        print(f"⏱️  Extracted {len(pacing_onsets_df)} pacing triggers from stim channels.")

        # --- 3. Define trials from pacing triggers ---
        trials_df = self.define_trials_from_pacing_onsets(pacing_onsets_df)
        if trials_df.empty:
            raise ValueError(f"❌ No valid trials defined for {self.subject}")
        print(f"🧩 Defined {len(trials_df)} trials.")

        # --- 4. Load binary events (behavioral/condition) ---
        events_df = self.load_binary_events()
        print(f"📊 Loaded {len(events_df)} binary events.")

        # --- 5. Assign events to trials ---
        events_with_trials = self.assign_events_to_trials(events_df, trials_df)
        print(f"✅ Assigned {len(events_with_trials)} events to trials.")

        # --- 6. Add stim_channel info ---
        final_df = self.add_stim_channel_info(events_with_trials, pacing_onsets_df)
        print(f"🏷️  Added stim_channel info to all events.")

        # --- 7. Final cleanup: select and sort columns ---
        output_columns = ['eeg_time_s', 'trial_number', 'condition', 'stim_channel']
        final_df = final_df[output_columns].sort_values(['trial_number', 'eeg_time_s']).reset_index(drop=True)

        # --- 8. Optionally save to CSV ---
        if self.save_output:
            output_file = self.output_dir / "events_with_trials.csv"
            final_df.to_csv(output_file, index=False)
            print(f"✅ Saved final CSV: {output_file}")

        print(f"🎉 Done processing {self.subject} — returning DataFrame with {len(final_df)} rows.\n")
        return final_df  # 👈 THIS IS YOUR FINAL OUTPUT


def find_all_subjects(project_base: Path):
    """Find all subjects with required files."""
    eeg_dir = project_base / "derivatives" / "eeg"
    subjects = []

    for item in eeg_dir.iterdir():
        if item.is_dir() and item.name.startswith("sub-"):
            session_dir = item / "bima_DBSOFF"
            if not session_dir.exists():
                continue

            # Must have RAW file + binary events
            raw_file = session_dir / f"{item.name}_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif"
            events_file = session_dir / f"{item.name}_events_mne_binary-eve.fif"
            event_id_file = session_dir / f"{item.name}_event_id_binary.json"

            if raw_file.exists() and events_file.exists() and event_id_file.exists():
                subjects.append(item.name)

    subjects.sort(key=lambda x: int(x.split('-')[1]))
    return subjects


# ========================
# 🔥 FIXED: PHASE SEGMENT DETECTION — stim_channel taken from OUT-PHASE WINDOW
# ========================

def find_phase_segments_per_trial(df, subject="unknown", min_in_phase_duration=3.0, max_outphase_in_inphase=1):
    """
    ✅ FINAL STRICT VERSION:
    - Find first 'OutofPhase' event occurring AFTER min_in_phase_duration (default=5s).
    - Check that in the 10s BEFORE, there are ≤ max_outphase_in_inphase (default=2) OutofPhase events.
    - If not, skip and look for next candidate.
    - Extract 10s BEFORE (in-phase) and 10s AFTER (out-of-phase).
    - Use stim_channel from the break event itself.
    """
    if df.empty:
        print(f"⚠️  No events to process for {subject}")
        return pd.DataFrame()

    # Ensure required columns exist
    required_cols = ['eeg_time_s', 'trial_number', 'condition', 'stim_channel']
    missing = [col for col in required_cols if col not in df.columns]
    if missing:
        raise ValueError(f"❌ Missing columns in data for {subject}: {missing}")

    results = []

    # Group by trial
    for trial_num, trial_group in df.groupby('trial_number'):
        try:
            trial_group = trial_group.sort_values('eeg_time_s').reset_index(drop=True)
            if len(trial_group) == 0:
                continue

            trial_start = trial_group['eeg_time_s'].min()
            trial_end = trial_group['eeg_time_s'].max()

            # Find ALL OutofPhase events AFTER minimum in-phase duration
            min_break_time = trial_start + min_in_phase_duration
            candidate_events = trial_group[
                (trial_group['condition'] == 'OutofPhase') &
                (trial_group['eeg_time_s'] >= min_break_time)
            ].sort_values('eeg_time_s')

            if len(candidate_events) == 0:
                print(f"⏭️  No phase break candidates in trial {trial_num} for {subject} (no OutofPhase after {min_in_phase_duration:.1f}s)")
                continue

            valid_break_found = False

            # Check each candidate break
            for _, first_out in candidate_events.iterrows():
                break_time = first_out['eeg_time_s']
                stim_ch = first_out['stim_channel']

                # Define 10s in-phase window BEFORE break
                in_phase_start = max(break_time - 10.0, trial_start)
                in_phase_end = break_time

                # Get events in in-phase window
                in_events = trial_group[
                    (trial_group['eeg_time_s'] >= in_phase_start) &
                    (trial_group['eeg_time_s'] < in_phase_end)
                ]

                # Count OutofPhase events in in-phase window
                n_out_in_inphase = (in_events['condition'] == 'OutofPhase').sum()

                # ✅ STRICT RULE: Reject if too many OutofPhase events in "in-phase" window
                if n_out_in_inphase > max_outphase_in_inphase:
                    print(f"   ⚠️  Skipping break at {break_time:.2f}s (trial {trial_num}): {n_out_in_inphase} OutofPhase events in in-phase window (max allowed: {max_outphase_in_inphase})")
                    continue

                # ✅ VALID BREAK FOUND
                out_phase_start = break_time
                out_phase_end = min(break_time + 10.0, trial_end)

                # Get events in out-phase window
                out_events = trial_group[
                    (trial_group['eeg_time_s'] >= out_phase_start) &
                    (trial_group['eeg_time_s'] < out_phase_end)
                ]

                results.append({
                    'subject': subject,
                    'trial_number': trial_num,
                    'stim_channel': stim_ch,
                    'break_time': break_time,
                    'in_phase_start': in_phase_start,
                    'in_phase_end': in_phase_end,
                    'out_phase_start': out_phase_start,
                    'out_phase_end': out_phase_end,
                    'n_in_phase_events': len(in_events),
                    'n_out_phase_events': len(out_events),
                    'n_outphase_in_inphase': n_out_in_inphase,  # 👈 NEW: explicit count
                    'n_inphase_in_inphase': (in_events['condition'] == 'InPhase').sum(),
                    'in_phase_condition_counts': in_events['condition'].value_counts().to_dict(),
                    'out_phase_condition_counts': out_events['condition'].value_counts().to_dict(),
                })

                print(f"✅ ACCEPTED phase break for {subject} trial {trial_num}: "
                      f"at {break_time:.2f}s (stim={stim_ch}) | "
                      f"In-phase [{in_phase_start:.2f}-{in_phase_end:.2f}] → {n_out_in_inphase} OutofPhase (≤{max_outphase_in_inphase}) | "
                      f"Out-phase [{out_phase_start:.2f}-{out_phase_end:.2f}]")

                valid_break_found = True
                break  # Take first VALID break

            if not valid_break_found:
                print(f"⏭️  No VALID phase break found in trial {trial_num} for {subject} (all candidates had too many OutofPhase events in pre-window)")

        except Exception as e:
            print(f"❌ Error processing trial {trial_num} for {subject}: {e}")
            continue

    if not results:
        print(f"❌ No valid phase breaks found for {subject}")
        return pd.DataFrame()

    result_df = pd.DataFrame(results)
    print(f"📊 Summary for {subject}: {len(result_df)} trials with STRICTLY VALID phase breaks")
    return result_df

    
# ========================
# 🧩 MAIN EXECUTION — Process all subjects and extract phase segments
# ========================

if __name__ == "__main__":
    print("="*80)
    print("🔎 STEP 1: Discovering subjects...")
    print("="*80)

    subjects = find_all_subjects(Path(PROJECT_BASE))
    if not subjects:
        print("❌ No valid subjects found.")
        exit(1)

    print(f"✅ Found {len(subjects)} subjects: {subjects}")

    # Output directory for phase segments
    PHASE_OUTPUT_DIR = Path(PROJECT_BASE) / "derivatives" / "phase_segments"
    PHASE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

    all_phase_segments = []

    print("\n" + "="*80)
    print("🧬 STEP 2: Processing each subject → events + phase segments")
    print("="*80)

    for subject in subjects:
        print(f"\n{'='*80}")
        print(f"🧬 PROCESSING SUBJECT: {subject}")
        print(f"{'='*80}")

        try:
            # --- 1. Generate events_with_trials.csv ---
            mapper = EventToTrialMapper(PROJECT_BASE, subject=subject, save_output=True)
            df = mapper.run()  # This saves CSV and returns DataFrame

            if df is None or len(df) == 0:
                print(f"❌ No event data for {subject}")
                continue

            # --- 2. Find phase segments ---
            print(f"\n🔍 STEP 3: Finding phase segments for {subject}...")
            segments_df = find_phase_segments_per_trial(df, subject=subject)

            if segments_df.empty:
                print(f"⏭️  No phase segments found for {subject}")
                continue

            # --- 3. Save per-subject phase segments ---
            phase_file = PHASE_OUTPUT_DIR / f"{subject}_phase_segments.csv"
            segments_df.to_csv(phase_file, index=False)
            print(f"✅ Saved phase segments: {phase_file}")

            # Collect for combined file
            all_phase_segments.append(segments_df)

        except Exception as e:
            print(f"❌ FAILED {subject}: {e}")
            continue

    # --- 4. Save combined phase segments ---
    if all_phase_segments:
        combined_df = pd.concat(all_phase_segments, ignore_index=True)
        combined_file = PHASE_OUTPUT_DIR / "all_subjects_phase_segments.csv"
        combined_df.to_csv(combined_file, index=False)
        print(f"\n🎉 SAVED COMBINED FILE: {combined_file}")
        print(f"📊 Total trials with phase segments: {len(combined_df)}")

        # Print stim_channel distribution to verify fix
        print("\n✅ STIM CHANNEL DISTRIBUTION (should NOT be all 1a):")
        print(combined_df['stim_channel'].value_counts().sort_index())

        # Show sample
        print("\n📋 SAMPLE OF CORRECTED DATA:")
        print(combined_df[['subject', 'trial_number', 'stim_channel', 'out_phase_start', 'in_phase_start']].head(10))

    else:
        print("\n❌ No phase segments found for any subject.")

    print(f"\n🎉🎉🎉 ALL DONE — Check output in: {PHASE_OUTPUT_DIR}")
# Out:
# ================================================================================
# 🔎 STEP 1: Discovering subjects...
# ================================================================================
# ✅ Found 12 subjects: ['sub-01', 'sub-02', 'sub-03', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-12', 'sub-14']
#
# ================================================================================
# 🧬 STEP 2: Processing each subject → events + phase segments
# ================================================================================
#
# ================================================================================
# 🧬 PROCESSING SUBJECT: sub-01
# ================================================================================
#
# 🚀 Processing sub-01 — extracting stim channels from RAW, defining trials, mapping events...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-01/bima_DBSOFF/sub-01_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 125209 ... 340681 =    250.418 ...   681.362 secs
# Ready.
# Reading 0 ... 215472  =      0.000 ...   430.944 secs...
# ⏱️  Extracted 1200 pacing triggers from stim channels.
# 🧩 Defined 10 trials.
# 📊 Loaded 578 binary events.
# ✅ Assigned 505 events to trials.
# 🏷️  Added stim_channel info to all events.
# ✅ Saved final CSV: /home/jaizor/jaizor/xtra/derivatives/features/sub-01/events_with_trials.csv
# 🎉 Done processing sub-01 — returning DataFrame with 505 rows.
#
#
# 🔍 STEP 3: Finding phase segments for sub-01...
#    ⚠️  Skipping break at 6.47s (trial 1): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 7.55s (trial 1): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 8.22s (trial 1): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 9.83s (trial 1): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 10.00s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 13.27s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 13.62s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 14.67s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 17.28s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 18.67s (trial 1): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 20.08s (trial 1): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 20.70s (trial 1): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 21.37s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 22.70s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 23.68s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 24.57s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 25.32s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 26.65s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 28.98s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 29.57s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 30.13s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 32.55s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 33.57s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 33.75s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 34.60s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 36.50s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 37.40s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 38.40s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 39.37s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 39.55s (trial 1): 10 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 1 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 50.58s (trial 2): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 51.37s (trial 2): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 51.87s (trial 2): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 53.52s (trial 2): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 53.70s (trial 2): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 54.65s (trial 2): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 54.88s (trial 2): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 57.57s (trial 2): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 59.78s (trial 2): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 61.88s (trial 2): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 63.70s (trial 2): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 65.30s (trial 2): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 66.00s (trial 2): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 68.05s (trial 2): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 68.97s (trial 2): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 69.77s (trial 2): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 70.43s (trial 2): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 70.95s (trial 2): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 71.98s (trial 2): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 72.17s (trial 2): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 73.18s (trial 2): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 73.88s (trial 2): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 74.60s (trial 2): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 79.95s (trial 2): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 81.93s (trial 2): 6 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 2 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 93.80s (trial 3): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 96.90s (trial 3): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 97.08s (trial 3): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 98.97s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 101.02s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 102.27s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 103.50s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 103.72s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 106.12s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 106.98s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 107.20s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 109.42s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 109.57s (trial 3): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 111.20s (trial 3): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 111.77s (trial 3): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 112.97s (trial 3): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 113.20s (trial 3): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 114.75s (trial 3): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 117.53s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 121.20s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 122.87s (trial 3): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 126.03s (trial 3): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 127.22s (trial 3): 4 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 3 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 136.97s (trial 4): 2 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 139.15s (trial 4): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 139.40s (trial 4): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 140.07s (trial 4): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 140.22s (trial 4): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 141.13s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 147.48s (trial 4): 5 OutofPhase events in in-phase window (max allowed: 1)
# ✅ ACCEPTED phase break for sub-01 trial 4: at 154.78s (stim=4a) | In-phase [144.78-154.78] → 1 OutofPhase (≤1) | Out-phase [154.78-164.78]
#    ⚠️  Skipping break at 181.12s (trial 5): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 181.62s (trial 5): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 183.83s (trial 5): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 184.47s (trial 5): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 185.05s (trial 5): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 185.28s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 186.18s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 186.98s (trial 5): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 188.15s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 188.38s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 192.07s (trial 5): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 192.40s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 193.62s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 195.75s (trial 5): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 196.93s (trial 5): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 202.68s (trial 5): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 205.35s (trial 5): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 207.88s (trial 5): 2 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 208.70s (trial 5): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 214.13s (trial 5): 3 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 5 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 224.27s (trial 6): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 224.98s (trial 6): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 227.03s (trial 6): 7 OutofPhase events in in-phase window (max allowed: 1)
# ✅ ACCEPTED phase break for sub-01 trial 6: at 235.20s (stim=2a) | In-phase [225.20-235.20] → 1 OutofPhase (≤1) | Out-phase [235.20-245.20]
#    ⚠️  Skipping break at 269.10s (trial 7): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 273.33s (trial 7): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 277.43s (trial 7): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 278.02s (trial 7): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 279.55s (trial 7): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 281.62s (trial 7): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 281.72s (trial 7): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 282.48s (trial 7): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 283.20s (trial 7): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 285.98s (trial 7): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 286.97s (trial 7): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 287.18s (trial 7): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 288.65s (trial 7): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 289.55s (trial 7): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 290.92s (trial 7): 9 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 7 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 312.63s (trial 8): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 312.83s (trial 8): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 314.75s (trial 8): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 315.67s (trial 8): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 316.35s (trial 8): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 317.02s (trial 8): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 318.52s (trial 8): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 319.48s (trial 8): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 319.63s (trial 8): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 320.38s (trial 8): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 322.10s (trial 8): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 322.65s (trial 8): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 323.43s (trial 8): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 328.07s (trial 8): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 330.30s (trial 8): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 334.73s (trial 8): 2 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 336.23s (trial 8): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 338.47s (trial 8): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 340.90s (trial 8): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 342.82s (trial 8): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 343.62s (trial 8): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 344.15s (trial 8): 6 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 8 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 357.47s (trial 9): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 358.20s (trial 9): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 358.82s (trial 9): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 359.07s (trial 9): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 361.63s (trial 9): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 362.70s (trial 9): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 364.73s (trial 9): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 367.23s (trial 9): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 368.23s (trial 9): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 369.65s (trial 9): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 371.80s (trial 9): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 372.82s (trial 9): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 375.32s (trial 9): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 375.58s (trial 9): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 376.43s (trial 9): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 379.38s (trial 9): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 379.57s (trial 9): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 380.52s (trial 9): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 381.03s (trial 9): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 381.77s (trial 9): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 383.50s (trial 9): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 384.28s (trial 9): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 385.97s (trial 9): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 386.08s (trial 9): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 387.92s (trial 9): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 388.40s (trial 9): 10 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 9 for sub-01 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 398.82s (trial 10): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 401.87s (trial 10): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 402.28s (trial 10): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 402.43s (trial 10): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 404.97s (trial 10): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 405.03s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 405.98s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 407.42s (trial 10): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 408.20s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 408.73s (trial 10): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 409.67s (trial 10): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 410.60s (trial 10): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 411.93s (trial 10): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 413.95s (trial 10): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 415.25s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 416.52s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 418.20s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 419.03s (trial 10): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 420.23s (trial 10): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 420.38s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 421.12s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 422.98s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 423.55s (trial 10): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 425.22s (trial 10): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 427.55s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 428.62s (trial 10): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 428.77s (trial 10): 9 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 10 for sub-01 (all candidates had too many OutofPhase events in pre-window)
# 📊 Summary for sub-01: 2 trials with STRICTLY VALID phase breaks
# ✅ Saved phase segments: /home/jaizor/jaizor/xtra/derivatives/phase_segments/sub-01_phase_segments.csv
#
# ================================================================================
# 🧬 PROCESSING SUBJECT: sub-02
# ================================================================================
#
# 🚀 Processing sub-02 — extracting stim channels from RAW, defining trials, mapping events...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-02/bima_DBSOFF/sub-02_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 57645 ... 306110 =    115.290 ...   612.220 secs
# Ready.
# Reading 0 ... 248465  =      0.000 ...   496.930 secs...
# ⏱️  Extracted 1200 pacing triggers from stim channels.
# 🧩 Defined 10 trials.
# 📊 Loaded 288 binary events.
# ✅ Assigned 244 events to trials.
# 🏷️  Added stim_channel info to all events.
# ✅ Saved final CSV: /home/jaizor/jaizor/xtra/derivatives/features/sub-02/events_with_trials.csv
# 🎉 Done processing sub-02 — returning DataFrame with 244 rows.
#
#
# 🔍 STEP 3: Finding phase segments for sub-02...
# ✅ ACCEPTED phase break for sub-02 trial 1: at 22.30s (stim=3a) | In-phase [12.30-22.30] → 0 OutofPhase (≤1) | Out-phase [22.30-32.30]
# ✅ ACCEPTED phase break for sub-02 trial 2: at 73.35s (stim=3a) | In-phase [63.35-73.35] → 0 OutofPhase (≤1) | Out-phase [73.35-83.35]
# ✅ ACCEPTED phase break for sub-02 trial 3: at 123.53s (stim=3a) | In-phase [113.53-123.53] → 0 OutofPhase (≤1) | Out-phase [123.53-133.53]
# ✅ ACCEPTED phase break for sub-02 trial 4: at 183.70s (stim=5a) | In-phase [173.70-183.70] → 0 OutofPhase (≤1) | Out-phase [183.70-193.70]
# ✅ ACCEPTED phase break for sub-02 trial 5: at 235.65s (stim=5a) | In-phase [225.65-235.65] → 0 OutofPhase (≤1) | Out-phase [235.65-245.65]
# ✅ ACCEPTED phase break for sub-02 trial 6: at 282.58s (stim=4a) | In-phase [272.58-282.58] → 0 OutofPhase (≤1) | Out-phase [282.58-292.58]
# ✅ ACCEPTED phase break for sub-02 trial 7: at 331.53s (stim=4a) | In-phase [321.53-331.53] → 0 OutofPhase (≤1) | Out-phase [331.53-341.53]
# ✅ ACCEPTED phase break for sub-02 trial 8: at 383.25s (stim=4a) | In-phase [373.25-383.25] → 0 OutofPhase (≤1) | Out-phase [383.25-393.25]
# ✅ ACCEPTED phase break for sub-02 trial 9: at 439.80s (stim=5a) | In-phase [429.80-439.80] → 0 OutofPhase (≤1) | Out-phase [439.80-447.77]
# ✅ ACCEPTED phase break for sub-02 trial 10: at 479.63s (stim=3a) | In-phase [469.63-479.63] → 0 OutofPhase (≤1) | Out-phase [479.63-489.63]
# 📊 Summary for sub-02: 10 trials with STRICTLY VALID phase breaks
# ✅ Saved phase segments: /home/jaizor/jaizor/xtra/derivatives/phase_segments/sub-02_phase_segments.csv
#
# ================================================================================
# 🧬 PROCESSING SUBJECT: sub-03
# ================================================================================
#
# 🚀 Processing sub-03 — extracting stim channels from RAW, defining trials, mapping events...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-03/bima_DBSOFF/sub-03_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 28559 ... 155095 =    114.236 ...   620.380 secs
# Ready.
# Reading 0 ... 126536  =      0.000 ...   506.144 secs...
# ⏱️  Extracted 1200 pacing triggers from stim channels.
# 🧩 Defined 10 trials.
# 📊 Loaded 645 binary events.
# ✅ Assigned 545 events to trials.
# 🏷️  Added stim_channel info to all events.
# ✅ Saved final CSV: /home/jaizor/jaizor/xtra/derivatives/features/sub-03/events_with_trials.csv
# 🎉 Done processing sub-03 — returning DataFrame with 545 rows.
#
#
# 🔍 STEP 3: Finding phase segments for sub-03...
#    ⚠️  Skipping break at 5.46s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 6.01s (trial 1): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 6.41s (trial 1): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 7.09s (trial 1): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 7.23s (trial 1): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 7.51s (trial 1): 14 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 7.64s (trial 1): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 7.92s (trial 1): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 8.34s (trial 1): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 8.73s (trial 1): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 9.13s (trial 1): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 9.53s (trial 1): 20 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 9.66s (trial 1): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 9.93s (trial 1): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 10.33s (trial 1): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 10.66s (trial 1): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 10.97s (trial 1): 25 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 11.31s (trial 1): 26 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 11.66s (trial 1): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 12.02s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 12.66s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 13.01s (trial 1): 29 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 13.35s (trial 1): 30 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 13.67s (trial 1): 29 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 14.26s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 20.56s (trial 1): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 20.93s (trial 1): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 22.61s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 22.72s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 23.12s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 23.60s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 23.96s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 24.33s (trial 1): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 24.65s (trial 1): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 24.73s (trial 1): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 25.47s (trial 1): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 26.99s (trial 1): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 27.11s (trial 1): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 27.46s (trial 1): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 27.86s (trial 1): 14 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 27.96s (trial 1): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 28.40s (trial 1): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 28.50s (trial 1): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 28.99s (trial 1): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 29.41s (trial 1): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 29.51s (trial 1): 20 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 30.00s (trial 1): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 30.40s (trial 1): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 30.50s (trial 1): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 31.01s (trial 1): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 31.12s (trial 1): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 31.53s (trial 1): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 31.66s (trial 1): 25 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 31.97s (trial 1): 26 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 32.32s (trial 1): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 32.69s (trial 1): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 32.81s (trial 1): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 33.10s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 33.55s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 33.95s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 34.28s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 34.35s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 34.75s (trial 1): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 35.07s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 35.16s (trial 1): 29 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 35.57s (trial 1): 29 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 35.94s (trial 1): 30 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 36.26s (trial 1): 31 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 36.56s (trial 1): 32 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 36.90s (trial 1): 33 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 37.26s (trial 1): 32 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 37.59s (trial 1): 32 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 37.92s (trial 1): 32 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 38.24s (trial 1): 32 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 38.71s (trial 1): 31 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 39.05s (trial 1): 31 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 39.62s (trial 1): 30 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 40.54s (trial 1): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 41.61s (trial 1): 26 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 42.59s (trial 1): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 42.91s (trial 1): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 44.38s (trial 1): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 45.24s (trial 1): 17 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 1 for sub-03 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 56.46s (trial 2): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 56.97s (trial 2): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 57.50s (trial 2): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 57.86s (trial 2): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 58.22s (trial 2): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 58.62s (trial 2): 14 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 59.04s (trial 2): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 59.43s (trial 2): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 59.80s (trial 2): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 60.21s (trial 2): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 60.61s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 61.03s (trial 2): 20 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 61.46s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 61.79s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 63.06s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 63.43s (trial 2): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 63.77s (trial 2): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 64.10s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 64.73s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 65.30s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 65.37s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 66.16s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 66.51s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 67.03s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 67.06s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 67.32s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 67.59s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 68.26s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 68.55s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 69.51s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 69.60s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 70.56s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 71.59s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 72.36s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 73.16s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 73.92s (trial 2): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 74.31s (trial 2): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 74.57s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 75.11s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 75.50s (trial 2): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 76.03s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 77.51s (trial 2): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 78.05s (trial 2): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 78.34s (trial 2): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 78.61s (trial 2): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 78.69s (trial 2): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 79.14s (trial 2): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 79.57s (trial 2): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 79.66s (trial 2): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 80.09s (trial 2): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 80.19s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 80.70s (trial 2): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 80.82s (trial 2): 20 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 81.19s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 81.66s (trial 2): 21 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 82.21s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 82.70s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 83.19s (trial 2): 22 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 83.60s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 83.93s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 84.34s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 84.76s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 85.16s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 85.56s (trial 2): 23 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 85.99s (trial 2): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 86.38s (trial 2): 24 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 86.78s (trial 2): 25 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 86.88s (trial 2): 26 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 87.18s (trial 2): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 87.53s (trial 2): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 87.84s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 88.14s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 88.46s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 88.79s (trial 2): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 89.12s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 89.20s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 89.48s (trial 2): 29 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 89.54s (trial 2): 30 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 90.14s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 90.41s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 90.48s (trial 2): 29 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 91.11s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 91.96s (trial 2): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 92.51s (trial 2): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 92.56s (trial 2): 28 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 93.21s (trial 2): 27 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 94.48s (trial 2): 25 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 94.81s (trial 2): 25 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 95.32s (trial 2): 25 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 2 for sub-03 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 109.29s (trial 3): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 110.06s (trial 3): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 110.46s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 110.85s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 111.29s (trial 3): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 111.71s (trial 3): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 112.11s (trial 3): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 112.48s (trial 3): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 112.92s (trial 3): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 113.26s (trial 3): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 113.57s (trial 3): 14 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 113.91s (trial 3): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 114.62s (trial 3): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 114.94s (trial 3): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 115.26s (trial 3): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 115.58s (trial 3): 18 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 115.91s (trial 3): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 116.27s (trial 3): 20 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 117.36s (trial 3): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 117.92s (trial 3): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 118.51s (trial 3): 20 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 120.20s (trial 3): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 120.54s (trial 3): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 121.10s (trial 3): 19 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 122.79s (trial 3): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 125.89s (trial 3): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 129.45s (trial 3): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 129.55s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 130.05s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 130.41s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 131.93s (trial 3): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 132.42s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 132.91s (trial 3): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 133.43s (trial 3): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 133.95s (trial 3): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 134.87s (trial 3): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 135.25s (trial 3): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 136.05s (trial 3): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 136.44s (trial 3): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 137.13s (trial 3): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 137.23s (trial 3): 14 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 137.54s (trial 3): 15 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 137.61s (trial 3): 16 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 137.97s (trial 3): 17 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 138.10s (trial 3): 18 OutofPhase events in in-phase window (max allowed: 1)
# ...
# ✅ ACCEPTED phase break for sub-11 trial 4: at 199.42s (stim=5a) | In-phase [189.42-199.42] → 0 OutofPhase (≤1) | Out-phase [199.42-209.42]
# ✅ ACCEPTED phase break for sub-11 trial 5: at 220.25s (stim=1a) | In-phase [213.26-220.25] → 0 OutofPhase (≤1) | Out-phase [220.25-230.25]
# 📊 Summary for sub-11: 2 trials with STRICTLY VALID phase breaks
# ✅ Saved phase segments: /home/jaizor/jaizor/xtra/derivatives/phase_segments/sub-11_phase_segments.csv
#
# ================================================================================
# 🧬 PROCESSING SUBJECT: sub-12
# ================================================================================
#
# 🚀 Processing sub-12 — extracting stim channels from RAW, defining trials, mapping events...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-12/bima_DBSOFF/sub-12_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 32867 ... 243522 =     65.734 ...   487.044 secs
# Ready.
# Reading 0 ... 210655  =      0.000 ...   421.310 secs...
# ⏱️  Extracted 960 pacing triggers from stim channels.
# 🧩 Defined 8 trials.
# 📊 Loaded 272 binary events.
# ✅ Assigned 272 events to trials.
# 🏷️  Added stim_channel info to all events.
# ✅ Saved final CSV: /home/jaizor/jaizor/xtra/derivatives/features/sub-12/events_with_trials.csv
# 🎉 Done processing sub-12 — returning DataFrame with 272 rows.
#
#
# 🔍 STEP 3: Finding phase segments for sub-12...
# ✅ ACCEPTED phase break for sub-12 trial 1: at 28.28s (stim=3a) | In-phase [18.28-28.28] → 0 OutofPhase (≤1) | Out-phase [28.28-38.28]
# ✅ ACCEPTED phase break for sub-12 trial 2: at 81.67s (stim=3a) | In-phase [71.67-81.67] → 0 OutofPhase (≤1) | Out-phase [81.67-91.67]
# ✅ ACCEPTED phase break for sub-12 trial 3: at 122.82s (stim=2a) | In-phase [112.82-122.82] → 0 OutofPhase (≤1) | Out-phase [122.82-132.82]
#    ⚠️  Skipping break at 169.18s (trial 4): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 169.75s (trial 4): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 171.60s (trial 4): 2 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 171.75s (trial 4): 3 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 172.85s (trial 4): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 173.50s (trial 4): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 174.98s (trial 4): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 175.13s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 177.25s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 177.67s (trial 4): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 178.28s (trial 4): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 179.07s (trial 4): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 179.67s (trial 4): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 180.37s (trial 4): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 180.57s (trial 4): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 181.30s (trial 4): 13 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 187.05s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 189.85s (trial 4): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 190.03s (trial 4): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 190.88s (trial 4): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 191.82s (trial 4): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 194.00s (trial 4): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 195.42s (trial 4): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 196.72s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 197.82s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 199.38s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 200.10s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 201.48s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 202.78s (trial 4): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 203.00s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 204.30s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 206.20s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 207.23s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 207.33s (trial 4): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 209.48s (trial 4): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 209.85s (trial 4): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 211.28s (trial 4): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 212.20s (trial 4): 9 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 4 for sub-12 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 217.63s (trial 5): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 217.72s (trial 5): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 218.82s (trial 5): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 221.25s (trial 5): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 221.42s (trial 5): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 222.80s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 223.42s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 223.67s (trial 5): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 225.60s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 226.50s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 226.98s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 228.53s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 228.65s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 229.38s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 229.60s (trial 5): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 232.10s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 232.48s (trial 5): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 233.80s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 234.77s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 235.92s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 236.40s (trial 5): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 237.82s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 237.97s (trial 5): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 238.48s (trial 5): 12 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 241.52s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 242.30s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 242.85s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 244.43s (trial 5): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 244.57s (trial 5): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 246.47s (trial 5): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 251.17s (trial 5): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 251.32s (trial 5): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 253.47s (trial 5): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 254.83s (trial 5): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 255.47s (trial 5): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 256.53s (trial 5): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 257.12s (trial 5): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 259.78s (trial 5): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 260.83s (trial 5): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 261.22s (trial 5): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 265.15s (trial 5): 6 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 5 for sub-12 (all candidates had too many OutofPhase events in pre-window)
#    ⚠️  Skipping break at 272.15s (trial 6): 4 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 272.67s (trial 6): 5 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 272.83s (trial 6): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 273.80s (trial 6): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 274.93s (trial 6): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 276.65s (trial 6): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 277.87s (trial 6): 6 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 278.47s (trial 6): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 279.68s (trial 6): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 280.68s (trial 6): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 281.83s (trial 6): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 284.30s (trial 6): 7 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 284.43s (trial 6): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 285.27s (trial 6): 8 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 285.75s (trial 6): 9 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 285.97s (trial 6): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 286.53s (trial 6): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 287.27s (trial 6): 11 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 288.50s (trial 6): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 290.25s (trial 6): 10 OutofPhase events in in-phase window (max allowed: 1)
#    ⚠️  Skipping break at 292.22s (trial 6): 9 OutofPhase events in in-phase window (max allowed: 1)
# ⏭️  No VALID phase break found in trial 6 for sub-12 (all candidates had too many OutofPhase events in pre-window)
# 📊 Summary for sub-12: 3 trials with STRICTLY VALID phase breaks
# ✅ Saved phase segments: /home/jaizor/jaizor/xtra/derivatives/phase_segments/sub-12_phase_segments.csv
#
# ================================================================================
# 🧬 PROCESSING SUBJECT: sub-14
# ================================================================================
#
# 🚀 Processing sub-14 — extracting stim channels from RAW, defining trials, mapping events...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-14/bima_DBSOFF/sub-14_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 61063 ... 324418 =    122.126 ...   648.836 secs
# Ready.
# Reading 0 ... 263355  =      0.000 ...   526.710 secs...
# ⏱️  Extracted 1200 pacing triggers from stim channels.
# 🧩 Defined 10 trials.
# 📊 Loaded 108 binary events.
# ✅ Assigned 108 events to trials.
# 🏷️  Added stim_channel info to all events.
# ✅ Saved final CSV: /home/jaizor/jaizor/xtra/derivatives/features/sub-14/events_with_trials.csv
# 🎉 Done processing sub-14 — returning DataFrame with 108 rows.
#
#
# 🔍 STEP 3: Finding phase segments for sub-14...
# ✅ ACCEPTED phase break for sub-14 trial 1: at 47.73s (stim=6a) | In-phase [37.73-47.73] → 0 OutofPhase (≤1) | Out-phase [47.73-53.60]
# ✅ ACCEPTED phase break for sub-14 trial 2: at 98.82s (stim=6a) | In-phase [88.82-98.82] → 0 OutofPhase (≤1) | Out-phase [98.82-106.55]
# ✅ ACCEPTED phase break for sub-14 trial 3: at 154.17s (stim=6a) | In-phase [144.17-154.17] → 0 OutofPhase (≤1) | Out-phase [154.17-159.98]
# ✅ ACCEPTED phase break for sub-14 trial 4: at 202.68s (stim=5a) | In-phase [192.68-202.68] → 0 OutofPhase (≤1) | Out-phase [202.68-212.68]
# ✅ ACCEPTED phase break for sub-14 trial 5: at 254.98s (stim=5a) | In-phase [244.98-254.98] → 0 OutofPhase (≤1) | Out-phase [254.98-264.98]
# ✅ ACCEPTED phase break for sub-14 trial 6: at 308.50s (stim=5a) | In-phase [298.50-308.50] → 0 OutofPhase (≤1) | Out-phase [308.50-318.05]
# ✅ ACCEPTED phase break for sub-14 trial 7: at 360.50s (stim=5a) | In-phase [350.50-360.50] → 0 OutofPhase (≤1) | Out-phase [360.50-370.50]
# ✅ ACCEPTED phase break for sub-14 trial 8: at 383.35s (stim=1a) | In-phase [379.30-383.35] → 1 OutofPhase (≤1) | Out-phase [383.35-393.35]
# ✅ ACCEPTED phase break for sub-14 trial 9: at 456.47s (stim=4a) | In-phase [446.47-456.47] → 0 OutofPhase (≤1) | Out-phase [456.47-466.47]
# ✅ ACCEPTED phase break for sub-14 trial 10: at 485.73s (stim=1a) | In-phase [480.05-485.73] → 1 OutofPhase (≤1) | Out-phase [485.73-495.73]
# 📊 Summary for sub-14: 10 trials with STRICTLY VALID phase breaks
# ✅ Saved phase segments: /home/jaizor/jaizor/xtra/derivatives/phase_segments/sub-14_phase_segments.csv
#
# 🎉 SAVED COMBINED FILE: /home/jaizor/jaizor/xtra/derivatives/phase_segments/all_subjects_phase_segments.csv
# 📊 Total trials with phase segments: 74
#
# ✅ STIM CHANNEL DISTRIBUTION (should NOT be all 1a):
# stim_channel
# 1a     7
# 2a    16
# 3a    20
# 4a    10
# 5a    10
# 6a    11
# Name: count, dtype: int64
#
# 📋 SAMPLE OF CORRECTED DATA:
#   subject  trial_number stim_channel  out_phase_start  in_phase_start
# 0  sub-01             4           4a           154.78          144.78
# 1  sub-01             6           2a           235.20          225.20
# 2  sub-02             1           3a            22.30           12.30
# 3  sub-02             2           3a            73.35           63.35
# 4  sub-02             3           3a           123.53          113.53
# 5  sub-02             4           5a           183.70          173.70
# 6  sub-02             5           5a           235.65          225.65
# 7  sub-02             6           4a           282.58          272.58
# 8  sub-02             7           4a           331.53          321.53
# 9  sub-02             8           4a           383.25          373.25
#
# 🎉🎉🎉 ALL DONE — Check output in: /home/jaizor/jaizor/xtra/derivatives/phase_segments

# %%
import pandas as pd

# Load combined file
df = pd.read_csv("/home/jaizor/jaizor/xtra/derivatives/phase_segments/all_subjects_phase_segments.csv")

print(f"Found {len(df)} valid phase segments across {df['subject'].nunique()} subjects.")
# Out:
# Found 74 valid phase segments across 12 subjects.

# %%
df
# Out:
#    subject  trial_number stim_channel  break_time  in_phase_start  \
# 0   sub-01             4           4a      154.78          144.78
# 1   sub-01             6           2a      235.20          225.20
# 2   sub-02             1           3a       22.30           12.30
# 3   sub-02             2           3a       73.35           63.35
# 4   sub-02             3           3a      123.53          113.53
# ..     ...           ...          ...         ...             ...
# 69  sub-14             6           5a      308.50          298.50
# 70  sub-14             7           5a      360.50          350.50
# 71  sub-14             8           1a      383.35          379.30
# 72  sub-14             9           4a      456.47          446.47
# 73  sub-14            10           1a      485.73          480.05
#
#     in_phase_end  out_phase_start  out_phase_end  n_in_phase_events  \
# 0         154.78           154.78         164.78                 10
# 1         235.20           235.20         245.20                  9
# 2          22.30            22.30          32.30                  2
# 3          73.35            73.35          83.35                  2
# 4         123.53           123.53         133.53                  3
# ..           ...              ...            ...                ...
# 69        308.50           308.50         318.05                  0
# 70        360.50           360.50         370.50                  0
# 71        383.35           383.35         393.35                  1
# 72        456.47           456.47         466.47                  0
# 73        485.73           485.73         495.73                  1
#
#     n_out_phase_events  n_outphase_in_inphase  n_inphase_in_inphase  \
# 0                   15                      1                     9
# 1                   18                      1                     8
# 2                   17                      0                     2
# 3                   17                      0                     2
# 4                    8                      0                     3
# ..                 ...                    ...                   ...
# 69                   7                      0                     0
# 70                   6                      0                     0
# 71                   1                      1                     0
# 72                   5                      0                     0
# 73                   4                      1                     0
#
#           in_phase_condition_counts        out_phase_condition_counts
# 0   {'InPhase': 9, 'OutofPhase': 1}   {'OutofPhase': 8, 'InPhase': 7}
# 1   {'InPhase': 8, 'OutofPhase': 1}  {'InPhase': 11, 'OutofPhase': 7}
# 2                    {'InPhase': 2}  {'InPhase': 11, 'OutofPhase': 6}
# 3                    {'InPhase': 2}  {'InPhase': 12, 'OutofPhase': 5}
# 4                    {'InPhase': 3}   {'InPhase': 5, 'OutofPhase': 3}
# ..                              ...                               ...
# 69                               {}   {'OutofPhase': 6, 'InPhase': 1}
# 70                               {}                 {'OutofPhase': 6}
# 71                {'OutofPhase': 1}                 {'OutofPhase': 1}
# 72                               {}                 {'OutofPhase': 5}
# 73                {'OutofPhase': 1}                 {'OutofPhase': 4}
#
# [74 rows x 14 columns]

# %%
# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_validation_for_subject(subject, project_base=PROJECT_BASE, max_trials=5):
    """
    Validate phase segment detection by plotting:
    - Original behavioral events (InPhase/OutofPhase)
    - Stim channel transitions
    - Detected 10s in-phase / out-of-phase segments
    All aligned to EEG time.
    """
    print(f"\n🔍 VALIDATING PHASE SEGMENTS FOR {subject}...")

    # --- Load files ---
    base_path = Path(project_base)
    events_file = base_path / "derivatives" / "features" / subject / "events_with_trials.csv"
    segments_file = base_path / "derivatives" / "phase_segments" / f"{subject}_phase_segments.csv"
    raw_file = base_path / "derivatives" / "eeg" / subject / "bima_DBSOFF" / f"{subject}_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif"

    if not events_file.exists():
        print(f"❌ events_with_trials.csv not found for {subject}")
        return
    if not segments_file.exists():
        print(f"❌ phase_segments.csv not found for {subject}")
        return
    if not raw_file.exists():
        print(f"❌ RAW file not found for {subject}")
        return

    # Load data
    events_df = pd.read_csv(events_file)
    segments_df = pd.read_csv(segments_file)

    # Optional: Load raw to get total duration (for x-limits)
    try:
        raw = mne.io.read_raw_fif(str(raw_file), preload=False)
        total_duration = raw.times[-1]
    except:
        total_duration = events_df['eeg_time_s'].max() + 10

    # Get unique trials
    trials = sorted(events_df['trial_number'].unique())
    trials = trials[:max_trials]  # Limit for readability

    if len(trials) == 0:
        print(f"⚠️ No trials found for {subject}")
        return

    # Color maps
    condition_colors = {'InPhase': 'green', 'OutofPhase': 'red'}
    stim_colors = {
        '1a': '#FF6B6B', '2a': '#4ECDC4', '3a': '#45B7D1',
        '4a': '#96CEB4', '5a': '#FFEAA7', '6a': '#DDA0DD',
        'unknown': '#888888'
    }

    # Plot per trial
    for trial_num in trials:
        trial_events = events_df[events_df['trial_number'] == trial_num].sort_values('eeg_time_s')
        trial_segments = segments_df[segments_df['trial_number'] == trial_num]

        if len(trial_events) == 0:
            continue

        # Get time range
        tmin = trial_events['eeg_time_s'].min() - 2
        tmax = min(trial_events['eeg_time_s'].max() + 12, total_duration)

        fig, ax = plt.subplots(1, 1, figsize=(16, 6))

        # --- Plot events as vertical lines ---
        for _, row in trial_events.iterrows():
            color = condition_colors.get(row['condition'], 'gray')
            ax.axvline(row['eeg_time_s'], color=color, alpha=0.7, lw=2,
                      label=row['condition'] if row.name == trial_events.index[0] else "")
            # Annotate stim channel
            stim = row['stim_channel']
            ax.text(row['eeg_time_s'], ax.get_ylim()[1] * 0.95, stim,
                   rotation=90, fontsize=8, color=stim_colors.get(stim, '#000'),
                   verticalalignment='top', horizontalalignment='center')

        # --- Plot detected segments ---
        for _, seg in trial_segments.iterrows():
            # In-phase segment
            ax.axvspan(seg['in_phase_start'], seg['in_phase_end'],
                      color='blue', alpha=0.2, label='Detected In-Phase (10s)' if seg.name == 0 else "")
            # Out-of-phase segment
            ax.axvspan(seg['out_phase_start'], seg['out_phase_end'],
                      color='red', alpha=0.2, label='Detected Out-of-Phase (10s)' if seg.name == 0 else "")

            # Mark segment boundaries
            ax.axvline(seg['in_phase_start'], color='blue', linestyle='--', lw=1.5, alpha=0.8)
            ax.axvline(seg['out_phase_end'], color='red', linestyle='--', lw=1.5, alpha=0.8)

        # --- Labels and formatting ---
        ax.set_title(f"{subject} - Trial {trial_num} | EEG Time", fontweight='bold', fontsize=14)
        ax.set_xlabel("Time (s) - EEG Time", fontweight='bold')
        ax.set_ylabel("Events & Segments", fontweight='bold')
        ax.set_xlim(tmin, tmax)
        ax.grid(True, alpha=0.3)

        # Create legend without duplicates
        handles, labels = ax.get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        ax.legend(by_label.values(), by_label.keys(), loc='upper right')

        # Save plot
        output_dir = base_path / "derivatives" / "validation_plots"
        output_dir.mkdir(parents=True, exist_ok=True)
        plot_file = output_dir / f"{subject}_trial{trial_num}_validation.png"
        plt.tight_layout()
        plt.savefig(plot_file, dpi=300, bbox_inches='tight')
        plt.close()

        print(f"✅ Saved validation plot: {plot_file}")

        # Print summary
        n_in = len(trial_events[trial_events['condition'] == 'InPhase'])
        n_out = len(trial_events[trial_events['condition'] == 'OutofPhase'])
        n_segments = len(trial_segments)
        stim_summary = trial_events['stim_channel'].value_counts().to_dict()

        print(f"   📊 Trial {trial_num}: {n_in} InPhase, {n_out} OutofPhase events")
        print(f"   🎛️  Stim channels: {stim_summary}")
        print(f"   🟦🟥 Detected segments: {n_segments}")

    print(f"🎉 Validation plots generated for {subject}")

# %%
# %%
print("\n" + "="*80)
print("🔍 STEP 4: VALIDATING PHASE SEGMENTS WITH PLOTS")
print("="*80)

for subject in subjects:
    try:
        plot_validation_for_subject(subject, max_trials=5)  # Limit to 5 trials per subject
    except Exception as e:
        print(f"❌ Failed to generate validation plot for {subject}: {e}")
        continue

print(f"\n✅ ALL VALIDATION PLOTS SAVED TO: {Path(PROJECT_BASE) / 'derivatives' / 'validation_plots'}")
# Out:
# ================================================================================
# 🔍 STEP 4: VALIDATING PHASE SEGMENTS WITH PLOTS
# ================================================================================
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-01...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-01/bima_DBSOFF/sub-01_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 125209 ... 340681 =    250.418 ...   681.362 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-01_trial1_validation.png
#    📊 Trial 1: 6 InPhase, 33 OutofPhase events
#    🎛️  Stim channels: {'1a': 11, '6a': 10, '4a': 6, '3a': 5, '2a': 4, '5a': 3}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-01_trial2_validation.png
#    📊 Trial 2: 31 InPhase, 29 OutofPhase events
#    🎛️  Stim channels: {'3a': 13, '1a': 11, '6a': 11, '4a': 11, '2a': 7, '5a': 7}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-01_trial3_validation.png
#    📊 Trial 3: 9 InPhase, 26 OutofPhase events
#    🎛️  Stim channels: {'1a': 8, '3a': 7, '4a': 7, '6a': 6, '2a': 5, '5a': 2}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-01_trial4_validation.png
#    📊 Trial 4: 28 InPhase, 22 OutofPhase events
#    🎛️  Stim channels: {'1a': 13, '2a': 10, '6a': 10, '5a': 8, '4a': 5, '3a': 4}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-01_trial5_validation.png
#    📊 Trial 5: 43 InPhase, 24 OutofPhase events
#    🎛️  Stim channels: {'1a': 13, '6a': 13, '5a': 12, '2a': 11, '4a': 11, '3a': 7}
#    🟦🟥 Detected segments: 0
# 🎉 Validation plots generated for sub-01
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-02...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-02/bima_DBSOFF/sub-02_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 57645 ... 306110 =    115.290 ...   612.220 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-02_trial1_validation.png
#    📊 Trial 1: 30 InPhase, 18 OutofPhase events
#    🎛️  Stim channels: {'5a': 17, '4a': 15, '6a': 8, '1a': 4, '3a': 3, '2a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-02_trial2_validation.png
#    📊 Trial 2: 30 InPhase, 17 OutofPhase events
#    🎛️  Stim channels: {'4a': 15, '6a': 14, '5a': 10, '1a': 5, '3a': 2, '2a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-02_trial3_validation.png
#    📊 Trial 3: 24 InPhase, 13 OutofPhase events
#    🎛️  Stim channels: {'6a': 15, '1a': 6, '5a': 6, '3a': 4, '2a': 3, '4a': 3}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-02_trial4_validation.png
#    📊 Trial 4: 2 InPhase, 11 OutofPhase events
#    🎛️  Stim channels: {'5a': 6, '6a': 5, '4a': 1, '1a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-02_trial5_validation.png
#    📊 Trial 5: 3 InPhase, 11 OutofPhase events
#    🎛️  Stim channels: {'6a': 6, '5a': 5, '1a': 2, '2a': 1}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-02
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-03...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-03/bima_DBSOFF/sub-03_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 28559 ... 155095 =    114.236 ...   620.380 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-03_trial1_validation.png
#    📊 Trial 1: 9 InPhase, 92 OutofPhase events
#    🎛️  Stim channels: {'1a': 30, '4a': 20, '5a': 17, '3a': 14, '6a': 13, '2a': 7}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-03_trial2_validation.png
#    📊 Trial 2: 12 InPhase, 98 OutofPhase events
#    🎛️  Stim channels: {'1a': 27, '6a': 19, '2a': 17, '4a': 17, '5a': 16, '3a': 14}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-03_trial3_validation.png
#    📊 Trial 3: 14 InPhase, 65 OutofPhase events
#    🎛️  Stim channels: {'1a': 19, '6a': 18, '5a': 15, '2a': 13, '4a': 11, '3a': 3}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-03_trial4_validation.png
#    📊 Trial 4: 35 InPhase, 73 OutofPhase events
#    🎛️  Stim channels: {'6a': 28, '2a': 21, '1a': 18, '3a': 17, '5a': 16, '4a': 8}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-03_trial5_validation.png
#    📊 Trial 5: 57 InPhase, 90 OutofPhase events
#    🎛️  Stim channels: {'3a': 43, '1a': 31, '6a': 22, '4a': 21, '2a': 15, '5a': 15}
#    🟦🟥 Detected segments: 0
# 🎉 Validation plots generated for sub-03
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-05...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-05/bima_DBSOFF/sub-05_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 6941 ... 270457 =     13.882 ...   540.914 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-05_trial1_validation.png
#    📊 Trial 1: 13 InPhase, 23 OutofPhase events
#    🎛️  Stim channels: {'6a': 14, '5a': 7, '4a': 6, '3a': 4, '1a': 3, '2a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-05_trial2_validation.png
#    📊 Trial 2: 23 InPhase, 29 OutofPhase events
#    🎛️  Stim channels: {'4a': 17, '6a': 14, '3a': 7, '1a': 6, '5a': 5, '2a': 3}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-05_trial3_validation.png
#    📊 Trial 3: 17 InPhase, 17 OutofPhase events
#    🎛️  Stim channels: {'4a': 10, '5a': 7, '6a': 7, '1a': 5, '3a': 4, '2a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-05_trial4_validation.png
#    📊 Trial 4: 31 InPhase, 22 OutofPhase events
#    🎛️  Stim channels: {'3a': 18, '6a': 11, '4a': 10, '5a': 10, '2a': 2, '1a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-05_trial5_validation.png
#    📊 Trial 5: 24 InPhase, 18 OutofPhase events
#    🎛️  Stim channels: {'3a': 13, '5a': 10, '6a': 9, '4a': 7, '1a': 2, '2a': 1}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-05
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-06...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-06/bima_DBSOFF/sub-06_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 22047 ... 285569 =     44.094 ...   571.138 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-06_trial1_validation.png
#    📊 Trial 1: 34 InPhase, 30 OutofPhase events
#    🎛️  Stim channels: {'6a': 20, '3a': 12, '5a': 12, '4a': 10, '2a': 6, '1a': 4}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-06_trial2_validation.png
#    📊 Trial 2: 19 InPhase, 12 OutofPhase events
#    🎛️  Stim channels: {'6a': 17, '1a': 11, '2a': 1, '3a': 1, '5a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-06_trial3_validation.png
#    📊 Trial 3: 20 InPhase, 15 OutofPhase events
#    🎛️  Stim channels: {'1a': 10, '6a': 10, '5a': 7, '4a': 5, '2a': 2, '3a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-06_trial4_validation.png
#    📊 Trial 4: 2 InPhase, 15 OutofPhase events
#    🎛️  Stim channels: {'6a': 7, '1a': 4, '4a': 3, '5a': 2, '2a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-06_trial5_validation.png
#    📊 Trial 5: 3 InPhase, 12 OutofPhase events
#    🎛️  Stim channels: {'6a': 9, '3a': 3, '5a': 2, '1a': 1}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-06
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-07...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-07/bima_DBSOFF/sub-07_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 16931 ... 280445 =     33.862 ...   560.890 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-07_trial1_validation.png
#    📊 Trial 1: 13 InPhase, 30 OutofPhase events
#    🎛️  Stim channels: {'5a': 9, '3a': 8, '4a': 8, '6a': 8, '1a': 7, '2a': 3}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-07_trial2_validation.png
#    📊 Trial 2: 13 InPhase, 34 OutofPhase events
#    🎛️  Stim channels: {'2a': 11, '1a': 10, '4a': 8, '6a': 8, '5a': 7, '3a': 3}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-07_trial3_validation.png
#    📊 Trial 3: 3 InPhase, 22 OutofPhase events
#    🎛️  Stim channels: {'6a': 8, '3a': 6, '5a': 6, '1a': 2, '4a': 2, '2a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-07_trial4_validation.png
#    📊 Trial 4: 13 InPhase, 24 OutofPhase events
#    🎛️  Stim channels: {'1a': 11, '5a': 7, '6a': 6, '4a': 6, '3a': 4, '2a': 3}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-07_trial5_validation.png
#    📊 Trial 5: 17 InPhase, 27 OutofPhase events
#    🎛️  Stim channels: {'1a': 11, '4a': 8, '6a': 8, '2a': 6, '5a': 6, '3a': 5}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-07
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-08...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-08/bima_DBSOFF/sub-08_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 87080 ... 350560 =    174.160 ...   701.120 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-08_trial1_validation.png
#    📊 Trial 1: 7 InPhase, 9 OutofPhase events
#    🎛️  Stim channels: {'2a': 6, '1a': 4, '5a': 3, '4a': 2, '6a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-08_trial2_validation.png
#    📊 Trial 2: 2 InPhase, 2 OutofPhase events
#    🎛️  Stim channels: {'6a': 2, '1a': 1, '5a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-08_trial3_validation.png
#    📊 Trial 3: 1 InPhase, 3 OutofPhase events
#    🎛️  Stim channels: {'6a': 3, '3a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-08_trial4_validation.png
#    📊 Trial 4: 2 InPhase, 4 OutofPhase events
#    🎛️  Stim channels: {'6a': 4, '1a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-08_trial5_validation.png
#    📊 Trial 5: 1 InPhase, 6 OutofPhase events
#    🎛️  Stim channels: {'6a': 5, '1a': 1, '5a': 1}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-08
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-09...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-09/bima_DBSOFF/sub-09_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 21695 ... 285200 =     43.390 ...   570.400 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-09_trial1_validation.png
#    📊 Trial 1: 12 InPhase, 18 OutofPhase events
#    🎛️  Stim channels: {'6a': 12, '1a': 6, '5a': 5, '4a': 4, '3a': 2, '2a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-09_trial2_validation.png
#    📊 Trial 2: 6 InPhase, 18 OutofPhase events
#    🎛️  Stim channels: {'6a': 8, '4a': 6, '5a': 6, '1a': 2, '2a': 1, '3a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-09_trial3_validation.png
#    📊 Trial 3: 3 InPhase, 17 OutofPhase events
#    🎛️  Stim channels: {'6a': 8, '5a': 6, '4a': 3, '3a': 2, '1a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-09_trial4_validation.png
#    📊 Trial 4: 19 InPhase, 20 OutofPhase events
#    🎛️  Stim channels: {'5a': 17, '6a': 13, '3a': 4, '1a': 3, '2a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-09_trial5_validation.png
#    📊 Trial 5: 25 InPhase, 20 OutofPhase events
#    🎛️  Stim channels: {'6a': 16, '4a': 9, '5a': 7, '1a': 7, '3a': 4, '2a': 2}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-09
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-10...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-10/bima_DBSOFF/sub-10_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 30050 ... 293573 =     60.100 ...   587.146 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-10_trial1_validation.png
#    📊 Trial 1: 22 InPhase, 12 OutofPhase events
#    🎛️  Stim channels: {'3a': 13, '4a': 5, '6a': 5, '1a': 4, '5a': 4, '2a': 3}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-10_trial2_validation.png
#    📊 Trial 2: 6 InPhase, 16 OutofPhase events
#    🎛️  Stim channels: {'6a': 8, '4a': 5, '1a': 4, '5a': 3, '2a': 1, '3a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-10_trial3_validation.png
#    📊 Trial 3: 6 InPhase, 12 OutofPhase events
#    🎛️  Stim channels: {'6a': 9, '4a': 6, '2a': 2, '1a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-10_trial4_validation.png
#    📊 Trial 4: 39 InPhase, 11 OutofPhase events
#    🎛️  Stim channels: {'6a': 18, '4a': 18, '3a': 5, '2a': 4, '5a': 3, '1a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-10_trial5_validation.png
#    📊 Trial 5: 29 InPhase, 7 OutofPhase events
#    🎛️  Stim channels: {'6a': 27, '5a': 5, '2a': 2, '1a': 1, '4a': 1}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-10
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-11...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-11/bima_DBSOFF/sub-11_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 7529 ... 139207 =     30.116 ...   556.828 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-11_trial1_validation.png
#    📊 Trial 1: 42 InPhase, 62 OutofPhase events
#    🎛️  Stim channels: {'2a': 32, '1a': 22, '6a': 20, '3a': 14, '5a': 9, '4a': 7}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-11_trial2_validation.png
#    📊 Trial 2: 41 InPhase, 69 OutofPhase events
#    🎛️  Stim channels: {'6a': 28, '2a': 24, '1a': 23, '5a': 21, '3a': 9, '4a': 5}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-11_trial3_validation.png
#    📊 Trial 3: 53 InPhase, 79 OutofPhase events
#    🎛️  Stim channels: {'3a': 36, '6a': 32, '1a': 24, '2a': 16, '4a': 14, '5a': 10}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-11_trial4_validation.png
#    📊 Trial 4: 40 InPhase, 71 OutofPhase events
#    🎛️  Stim channels: {'1a': 37, '6a': 33, '2a': 19, '5a': 12, '3a': 9, '4a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-11_trial5_validation.png
#    📊 Trial 5: 62 InPhase, 47 OutofPhase events
#    🎛️  Stim channels: {'2a': 36, '6a': 32, '5a': 18, '1a': 10, '3a': 7, '4a': 6}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-11
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-12...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-12/bima_DBSOFF/sub-12_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 32867 ... 243522 =     65.734 ...   487.044 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-12_trial1_validation.png
#    📊 Trial 1: 10 InPhase, 9 OutofPhase events
#    🎛️  Stim channels: {'1a': 5, '3a': 5, '6a': 4, '2a': 2, '5a': 2, '4a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-12_trial2_validation.png
#    📊 Trial 2: 17 InPhase, 19 OutofPhase events
#    🎛️  Stim channels: {'6a': 13, '4a': 7, '3a': 6, '1a': 6, '2a': 2, '5a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-12_trial3_validation.png
#    📊 Trial 3: 42 InPhase, 22 OutofPhase events
#    🎛️  Stim channels: {'4a': 16, '3a': 16, '6a': 15, '2a': 8, '5a': 6, '1a': 3}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-12_trial4_validation.png
#    📊 Trial 4: 4 InPhase, 41 OutofPhase events
#    🎛️  Stim channels: {'2a': 11, '1a': 9, '6a': 9, '4a': 6, '3a': 5, '5a': 5}
#    🟦🟥 Detected segments: 0
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-12_trial5_validation.png
#    📊 Trial 5: 27 InPhase, 45 OutofPhase events
#    🎛️  Stim channels: {'1a': 21, '6a': 16, '2a': 14, '3a': 10, '5a': 6, '4a': 5}
#    🟦🟥 Detected segments: 0
# 🎉 Validation plots generated for sub-12
#
# 🔍 VALIDATING PHASE SEGMENTS FOR sub-14...
# Opening raw data file /home/jaizor/jaizor/xtra/derivatives/eeg/sub-14/bima_DBSOFF/sub-14_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif...
#     Range : 61063 ... 324418 =    122.126 ...   648.836 secs
# Ready.
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-14_trial1_validation.png
#    📊 Trial 1: 1 InPhase, 5 OutofPhase events
#    🎛️  Stim channels: {'6a': 4, '1a': 2}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-14_trial2_validation.png
#    📊 Trial 2: 1 InPhase, 9 OutofPhase events
#    🎛️  Stim channels: {'6a': 9, '1a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-14_trial3_validation.png
#    📊 Trial 3: 0 InPhase, 7 OutofPhase events
#    🎛️  Stim channels: {'6a': 6, '1a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-14_trial4_validation.png
#    📊 Trial 4: 1 InPhase, 10 OutofPhase events
#    🎛️  Stim channels: {'6a': 8, '5a': 2, '1a': 1}
#    🟦🟥 Detected segments: 1
# ✅ Saved validation plot: /home/jaizor/jaizor/xtra/derivatives/validation_plots/sub-14_trial5_validation.png
#    📊 Trial 5: 0 InPhase, 12 OutofPhase events
#    🎛️  Stim channels: {'6a': 9, '1a': 2, '5a': 1}
#    🟦🟥 Detected segments: 1
# 🎉 Validation plots generated for sub-14
#
# ✅ ALL VALIDATION PLOTS SAVED TO: /home/jaizor/jaizor/xtra/derivatives/validation_plots
