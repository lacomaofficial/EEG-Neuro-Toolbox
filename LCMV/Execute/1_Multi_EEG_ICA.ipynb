# %% [markdown]
# ## **Multi EEG-ICA Preproccesing Framework**

# %%
# FUNCTIONS

# Libraries
import os
import mne
import json
import scipy
import traceback
import numpy as np
from tqdm import tqdm
from scipy.stats import kurtosis
from typing import List, Dict, Tuple
from mne_icalabel import label_components


# Force non-interactive backend
import matplotlib
matplotlib.use('Agg')  # ← This prevents plots from showing
import matplotlib.pyplot as plt

mne.set_log_level('WARNING')


# =============================================================================
# 1. DEFINE EventTrimmer CLASS
# =============================================================================
class EventTrimmer:
    """
    Trim EEG data based on trigger channels, preserve stim channels, align events,
    and optionally save cropping metadata to JSON.
    """
    def __init__(
        self,
        raw_filtered: mne.io.Raw,
        output_path: str,
        subject: str,
        trigger_pairs: tuple = ('1a', '6a'),
        pre_time: float = 2.0,
        post_time: float = 2.0,
        stim_channels: List[str] = None,
        events_base: str = None,
        project_id: str = "Sbj01",
        plot: bool = False,
        save: bool = True,
        save_json: bool = True,
        align_events: bool = True
    ):
        self.raw = raw_filtered
        self.output_path = output_path
        self.subject = subject
        self.first_trig, self.last_trig = trigger_pairs
        self.pre_time = pre_time
        self.post_time = post_time
        self.stim_channels = stim_channels or ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
        self.events_base = events_base
        self.project_id = project_id
        self.plot = plot
        self.save = save
        self.save_json = save_json
        self.align_events = align_events

        if self.events_base is None:
            self.events_base = os.path.join(os.path.dirname(self.output_path), "Events")

        self.raw_cropped = None
        self.stim_raw = None
        self.onsets = {}
        self.tmin_trim = None
        self.tmax_trim = None

    def detect_onsets(self) -> Dict[str, np.ndarray]:
        sfreq = self.raw.info['sfreq']
        picks = [self.first_trig, self.last_trig]
        picks = [ch for ch in picks if ch in self.raw.ch_names]
        if len(picks) < 2:
            raise ValueError(f"Trigger channels missing: {picks}")

        data, times = self.raw[picks, :]
        sig_1a = data[0] if len(data) > 0 else np.zeros_like(times)
        sig_6a = data[1] if len(data) > 1 else np.zeros_like(times)

        def find_onsets(signal):
            diff = np.diff((signal > 0.5).astype(int))
            return np.where(diff == 1)[0] + 1

        onsets_1a = find_onsets(sig_1a) / sfreq
        onsets_6a = find_onsets(sig_6a) / sfreq
        self.onsets = {self.first_trig: onsets_1a, self.last_trig: onsets_6a}

        self._log(f"✅ {self.first_trig}: {len(onsets_1a)} onsets | First: {onsets_1a[0]:.3f}s")
        self._log(f"✅ {self.last_trig}: {len(onsets_6a)} onsets | Last: {onsets_6a[-1]:.3f}s")
        return self.onsets

    def _log(self, msg: str):
        """Use parent's log if available, otherwise print"""
        if hasattr(self, 'output_path') and hasattr(self, 'subject'):
            log_file = os.path.join(self.output_path, f"{self.subject}_preproc_log.txt")
            with open(log_file, 'a') as f:
                f.write(msg + '\n')
        print(msg)

    def trim_data(self) -> mne.io.Raw:
        onsets = self.onsets
        sfreq = self.raw.info['sfreq']
        tmax_orig = self.raw.times[-1]

        self.tmin_trim = max(0.0, onsets[self.first_trig][0] - self.pre_time)
        self.tmax_trim = min(tmax_orig, onsets[self.last_trig][-1] + self.post_time)

        self._log(f"\n✂️ Trimming data to: {self.tmin_trim:.3f}s → {self.tmax_trim:.3f}s "
                  f"({self.tmax_trim - self.tmin_trim:.2f}s)")

        self.raw_cropped = self.raw.copy().crop(tmin=self.tmin_trim, tmax=self.tmax_trim)

        if self.plot:
            self._plot_triggers_and_crop()

        if self.save_json:
            self._save_cropping_json()

        return self.raw_cropped

    def _plot_triggers_and_crop(self):
        raw = self.raw
        times = raw.times
        sig_1a = raw.get_data(picks=[self.first_trig])[0] if self.first_trig in raw.ch_names else np.zeros_like(times)
        sig_6a = raw.get_data(picks=[self.last_trig])[0] if self.last_trig in raw.ch_names else np.zeros_like(times)

        plt.figure(figsize=(16, 6))
        plt.plot(times, sig_6a, color='lavender', linewidth=1, label=self.last_trig)
        plt.vlines(self.onsets[self.first_trig], ymin=1.0, ymax=1.4, color='indigo', alpha=0.7, label=f"{self.first_trig} onsets")
        plt.vlines(self.onsets[self.last_trig], ymin=-0.2, ymax=0.2, color='darkviolet', alpha=0.7, label=f"{self.last_trig} onsets")
        plt.axvspan(self.tmin_trim, self.tmax_trim, color='azure', alpha=0.3, label="Cropped Region")
        plt.axvline(self.onsets[self.first_trig][0], color='purple', linestyle='--', linewidth=2, label=f"First '{self.first_trig}'")
        plt.axvline(self.onsets[self.last_trig][-1], color='indigo', linestyle='--', linewidth=2, label=f"Last '{self.last_trig}'")

        plt.title(f"Trigger Channels '{self.first_trig}' and '{self.last_trig}' — Trim Region", fontsize=14)
        plt.xlabel("Time (s)")
        plt.ylabel("Digital Signal")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.close()

    def _save_cropping_json(self):
        json_path = os.path.join(self.output_path, f"{self.subject}_cropping_info.json")
        crop_info = {
            "subject": self.subject,
            "tmin_trim": float(self.tmin_trim),
            "tmax_trim": float(self.tmax_trim),
            "duration_seconds": float(self.tmax_trim - self.tmin_trim),
            "first_trigger": self.first_trig,
            "last_trigger": self.last_trig,
            "pre_time_seconds": self.pre_time,
            "post_time_seconds": self.post_time,
            "onset_first_trigger_first": float(self.onsets[self.first_trig][0]),
            "onset_last_trigger_last": float(self.onsets[self.last_trig][-1]),
            "n_onsets_first_trigger": int(len(self.onsets[self.first_trig])),
            "n_onsets_last_trigger": int(len(self.onsets[self.last_trig])),
            "sampling_frequency": float(self.raw.info['sfreq']),
            "stim_channels_preserved": [ch for ch in self.stim_channels if ch in self.raw_cropped.ch_names],
            "cropped_n_samples": int(self.raw_cropped.n_times),
            "meas_date": self.raw_cropped.info.get('meas_date', None)
        }

        with open(json_path, 'w') as f:
            json.dump(crop_info, f, indent=2, default=str)
        self._log(f"📄 Cropping metadata saved to: {json_path}")

    def preserve_stim_channels(self) -> mne.io.RawArray:
        ch_names = [ch for ch in self.stim_channels if ch in self.raw_cropped.ch_names]
        if not ch_names:
            raise ValueError("No stim channels found after cropping.")
        data = self.raw_cropped.get_data(picks=ch_names)
        info = mne.create_info(ch_names, sfreq=self.raw_cropped.info['sfreq'], ch_types='stim')
        self.stim_raw = mne.io.RawArray(data, info)
        self.stim_raw.set_meas_date(self.raw_cropped.info['meas_date'])
        self._log(f"✅ Preserved stim channels: {ch_names}")
        return self.stim_raw

    def align_external_events(self):
        if not self.align_events or not self.save:
            self._log("⏭️ Skipping external event alignment (disabled).")
            return

        events_fif = os.path.join(self.events_base, f"{self.project_id}_events_mne_binary-eve.fif")
        events_json = os.path.join(self.events_base, f"{self.project_id}_event_id_binary.json")

        # Fixed: Gracefully handle missing files instead of crashing
        for path in [events_fif, events_json]:
            if not os.path.exists(path):
                self._log(f"⏭️ Skipping event alignment - missing file: {path}")
                return

        events_full = mne.read_events(events_fif)
        with open(events_json, 'r') as f:
            event_id = json.load(f)

        sfreq = self.raw.info['sfreq']
        event_times_sec = events_full[:, 0] / sfreq
        in_window = (event_times_sec >= self.tmin_trim) & (event_times_sec <= self.tmax_trim)
        events_cropped = events_full[in_window].copy()
        events_cropped[:, 0] -= int(self.tmin_trim * sfreq)

        event_id_clean = {k.replace('-', '').replace(' ', ''): v for k, v in event_id.items()}

        out_events = os.path.join(self.output_path, f"{self.subject}_events_mne_binary-eve.fif")
        out_id = os.path.join(self.output_path, f"{self.subject}_event_id_binary.json")

        mne.write_events(out_events, events_cropped, overwrite=True)
        with open(out_id, 'w') as f:
            json.dump(event_id_clean, f, indent=2)

        self._log("\n✅ EVENT ALIGNMENT COMPLETE")
        self._log(f"   Original events: {len(events_full)}")
        self._log(f"   After trimming:  {len(events_cropped)}")
        self._log(f"   Duration: {self.tmin_trim:.2f}s → {self.tmax_trim:.2f}s")
        self._log(f"   Events saved to: {out_events}")
        self._log(f"   Event ID saved to: {out_id}")
        self._log(f"   Event IDs: {event_id_clean}")

    def run(self) -> tuple[mne.io.Raw, mne.io.RawArray]:
        self._log("🔍 Starting event-based trimming...")
        self.detect_onsets()
        self.trim_data()
        self.preserve_stim_channels()
        self.align_external_events()
        self._log("✅ Trimming & event alignment complete.")
        return self.raw_cropped, self.stim_raw


# =============================================================================
# 2. DEFINE EEGICAProcessor CLASS
# =============================================================================
class EEGICAProcessor:
    def __init__(
        self,
        subject: str,
        session: str,
        task: str,
        mff_path: str,
        gpsc_file: str,
        events_base: str,
        project_id: str,
        base_output_path: str,
        trigger_pairs: Tuple[str, str] = ('1a', '6a'),
        pre_time: float = 2.0,
        post_time: float = 2.0,
        plot: bool = False,
        random_state: int = 99,
        log_to_file: bool = True
    ):
        self.subject = subject
        self.session = session
        self.task = task
        self.mff_path = mff_path
        self.gpsc_file = gpsc_file
        self.events_base = events_base
        self.project_id = project_id
        self.trigger_pairs = trigger_pairs
        self.pre_time = pre_time
        self.post_time = post_time
        self.plot = plot
        self.random_state = random_state
        self.log_to_file = log_to_file

        # Set up output path and subfolders
        self.output_path = os.path.join(base_output_path, subject, f"{task}_{session}")
        os.makedirs(self.output_path, exist_ok=True)
        os.makedirs(os.path.join(self.output_path, "plots"), exist_ok=True)

        self.log_file = os.path.join(self.output_path, f"{subject}_preproc_log.txt")
        if self.log_to_file:
            self._log(f"Initialized EEGICAProcessor for {subject}/{session}")

        self.raw = None
        self.raw_filtered = None
        self.raw_cropped = None
        self.stim_raw = None
        self.cleaned_data = None
        self.ica_obj = None



    def _log(self, msg: str, detail: str = "normal"):
        """
        Log messages:
        - 'normal': to both console and file
        - 'debug':  only to file
        """
        # Always write to file
        with open(self.log_file, 'a') as f:
            f.write(msg + '\n')
        
        # Only print to console if 'normal'
        if detail == "normal":
            print(msg)

    def load_and_montage(self):
        self._log("Loading raw data from .mff...")
        self.raw = mne.io.read_raw_egi(self.mff_path, preload=True)
        channel_map = {str(i): f'E{i}' for i in range(1, 281)}
        channel_map['REF CZ'] = 'Cz'
        self.raw.rename_channels(channel_map)
        self._log("Parsing and applying montage from .gpsc...")
        channels = self._parse_gpsc(self.gpsc_file)
        if not channels:
            raise ValueError("No valid channels in .gpsc file")
        gpsc_array = np.array([ch[1:4] for ch in channels])
        mean_pos = np.mean(gpsc_array, axis=0)
        self._log(f"Original mean position (mm): {mean_pos}")
        channels_normalized = [(ch[0], ch[1] - mean_pos[0], ch[2] - mean_pos[1], ch[3] - mean_pos[2]) for ch in channels]
        ch_pos = {ch[0]: np.array(ch[1:4]) / 1000.0 for ch in channels_normalized}
        fid_nz = ch_pos.get('FidNz')
        fid_t9 = ch_pos.get('FidT9')
        fid_t10 = ch_pos.get('FidT10')
        montage = mne.channels.make_dig_montage(ch_pos=ch_pos, nasion=fid_nz, lpa=fid_t9, rpa=fid_t10, coord_frame='head')
        self.raw.set_montage(montage, on_missing='warn')
        self._log("Montage applied.")

    def _parse_gpsc(self, filepath: str):
        channels = []
        with open(filepath, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) < 4:
                    continue
                name = parts[0]
                try:
                    x, y, z = map(float, parts[1:4])
                    channels.append((name, x, y, z))
                except ValueError:
                    continue
        return channels

    def filter_data(self):
        self._log("Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...")
        self.raw_filtered = self.raw.copy().filter(
            l_freq=1.0, h_freq=100.0, picks=['eeg'], method='fir', phase='zero',
            fir_window='hamming', fir_design='firwin', n_jobs=1
        )
        nyquist = self.raw_filtered.info["sfreq"] / 2
        notch_freqs = np.arange(60, nyquist, 60)
        self.raw_filtered.notch_filter(
            freqs=notch_freqs, picks='eeg', method='spectrum_fit',
            filter_length='auto', mt_bandwidth=1.0, p_value=0.05
        )
        if np.std(self.raw_filtered.get_data(picks=['Cz'])[0]) < 1e-6:
            self.raw_filtered.info['bads'].append('Cz')
            self._log("Marked Cz as bad (flat signal).")

    def trim_events(self):
        # ✅ Improved: Include TT*, *a, and specific event codes 'c', 'o', 'x'
        stim_chs = [
            ch for ch in self.raw_filtered.ch_names
            if 'TT' in ch or ch.endswith('a') or ch in ['c', 'o', 'x']
        ]
        self._log(f"Stim channels: {stim_chs}")

        trimmer = EventTrimmer(
            raw_filtered=self.raw_filtered,
            output_path=self.output_path,
            subject=self.subject,
            trigger_pairs=self.trigger_pairs,
            pre_time=self.pre_time,
            post_time=self.post_time,
            stim_channels=stim_chs,
            events_base=self.events_base,
            project_id=self.project_id,
            plot=self.plot,
            save_json=True,
            align_events=True
        )
        self.raw_cropped, self.stim_raw = trimmer.run()

    def detect_bad_channels(self):
        self._log("Detecting bad channels using MAD...")
        raw_eeg = self.raw_cropped.copy().pick("eeg")
        data_uV = raw_eeg.get_data() * 1e6
        mad_scores = [scipy.stats.median_abs_deviation(row, scale=1) for row in data_uV]
        median_mad = np.nanmedian(mad_scores)
        mad_mad = scipy.stats.median_abs_deviation(mad_scores, scale=1)
        z_scores = 0.6745 * (np.array(mad_scores) - median_mad) / mad_mad
        bads = [raw_eeg.ch_names[i] for i in np.where(np.abs(z_scores) >= 8.0)[0]]
        self.raw_cropped.info['bads'].extend(bads)
        self._log(f"Bad channels (MAD): {bads}")

    def run_automatic_ica_cleaning(self, eeg_data, n_components=0.99, random_state=99, cmap='plasma'):
        """Full ICA cleaning pipeline with artifact detection."""
        results = {}

        # === 1. Data Preparation ===
        raw = eeg_data.copy()
        vveog_anode, vveog_cathode = 'E31', 'E19'
        heog_anode, heog_cathode = 'E41', 'E274'
        ecg_anode, ecg_cathode = 'E227', 'E229'
        emg_chs = ['E280', 'E52']
        ft_chs = ['E31', 'E19']  # Used for frontal low-frequency artifacts

        raw.pick_types(eeg=True, eog=True, ecg=True, emg=True)
        raw.set_channel_types({'E280': 'emg', 'E52': 'emg'})
        raw_filtered = raw.copy()

        # === 2. Add Bipolar Reference Channels ===
        if all(ch in raw_filtered.ch_names for ch in [vveog_anode, vveog_cathode]):
            raw_filtered = mne.set_bipolar_reference(
                raw_filtered, anode=vveog_anode, cathode=vveog_cathode,
                ch_name='vVEOG', drop_refs=False
            ).set_channel_types({'vVEOG': 'eog'})
            self._log("Created vVEOG (E31-E19) for blink detection", detail="debug")

        if all(ch in raw_filtered.ch_names for ch in [heog_anode, heog_cathode]):
            raw_filtered = mne.set_bipolar_reference(
                raw_filtered, anode=heog_anode, cathode=heog_cathode,
                ch_name='BLINK_H', drop_refs=False
            ).set_channel_types({'BLINK_H': 'eog'})
            self._log("Created BLINK_H (E41-E274) for horizontal eye movement", detail="debug")

        if ecg_anode in raw_filtered.ch_names and ecg_cathode in raw_filtered.ch_names:
            raw_filtered = mne.set_bipolar_reference(
                raw_filtered, anode=ecg_anode, cathode=ecg_cathode,
                ch_name='ECG_BIO', drop_refs=False
            ).set_channel_types({'ECG_BIO': 'ecg'})
            self._log("Created ECG_BIO (E227-E229) for cardiac artifact detection", detail="debug")

        # === 3. Fit ICA ===
        self._log("Fitting ICA with Extended Infomax...", detail="debug")
        ica = mne.preprocessing.ICA(
            n_components=n_components,
            random_state=random_state,
            method='picard',
            fit_params=dict(ortho=False, extended=True),
            max_iter='auto'
        )
        try:
            ica.fit(raw_filtered)
            self._log(f"ICA fitted with {ica.n_components_} components", detail="debug")
        except Exception as e:
            self._log(f"❌ ICA fitting failed: {e}", detail="normal")
            raise

        # === 4. Artifact Detection ===
        ica.exclude = []
        blink_idx = []
        h_saccade_idx = []
        ecg_idx = []
        muscle_idx = []
        frontal_lf_idx = []  # Renamed from "drift"
        line_noise_idx = []

        # --- Blink Detection ---
        if 'vVEOG' in raw_filtered.ch_names:
            try:
                idx, _ = ica.find_bads_eog(raw_filtered, ch_name='vVEOG', measure='zscore', threshold=3.0)
                blink_idx = [int(i) for i in idx]
                ica.exclude.extend(blink_idx)
                self._log(f"Blink components detected: {blink_idx}", detail="debug")
            except Exception as e:
                self._log(f"Blink detection failed: {e}", detail="debug")

        # --- Horizontal Eye Movement ---
        if 'BLINK_H' in raw_filtered.ch_names:
            try:
                idx, _ = ica.find_bads_eog(raw_filtered, ch_name='BLINK_H', measure='zscore', threshold=3.0)
                h_saccade_idx = [int(i) for i in idx if i not in ica.exclude]
                ica.exclude.extend(h_saccade_idx)
                self._log(f"Horizontal eye components: {h_saccade_idx}", detail="debug")
            except Exception as e:
                self._log(f"Horizontal eye detection failed: {e}", detail="debug")

        # --- ECG Detection ---
        if 'ECG_BIO' in raw_filtered.ch_names:
            try:
                idx, _ = ica.find_bads_ecg(raw_filtered, ch_name='ECG_BIO', method='correlation', measure='zscore', threshold=3.0)
                ecg_idx = [int(i) for i in idx]
                ica.exclude.extend(ecg_idx)
                self._log(f"ECG components detected: {ecg_idx}", detail="debug")
            except Exception as e:
                self._log(f"ECG detection failed: {e}", detail="debug")

        # --- Muscle Artifacts ---
        self._log("Detecting muscle artifacts (30–100 Hz)...", detail="debug")
        for ch_name in emg_chs:
            if ch_name not in raw_filtered.ch_names:
                continue
            try:
                idx, _ = ica.find_bads_eog(
                    raw_filtered, ch_name=ch_name,
                    measure='zscore', l_freq=30, h_freq=100,
                    threshold=3.0
                )
                idx = [int(i) for i in idx]
                new_idx = [i for i in idx if i not in ica.exclude]
                muscle_idx.extend(new_idx)
                if new_idx:
                    self._log(f"Muscle components linked to {ch_name}: {new_idx}", detail="debug")
            except Exception as e:
                self._log(f"EMG detection failed for {ch_name}: {e}", detail="debug")
        muscle_idx = list(set(muscle_idx))
        ica.exclude.extend(muscle_idx)

        # --- Low-Frequency Frontal Artifacts (replaces "drift") ---
        self._log("Detecting low-frequency frontal artifacts (1–10 Hz) using E31/E19...", detail="debug")
        for ch_name in ft_chs:
            if ch_name not in raw_filtered.ch_names:
                continue
            try:
                idx, _ = ica.find_bads_eog(
                    raw_filtered, ch_name=ch_name,
                    measure='zscore', l_freq=1.0, h_freq=10.0, threshold=5.0
                )
                idx = [int(i) for i in idx]
                new_idx = [i for i in idx if i not in ica.exclude]
                frontal_lf_idx.extend(new_idx)
                if new_idx:
                    self._log(f"Frontal LF components linked to {ch_name}: {new_idx}", detail="debug")
            except Exception as e:
                self._log(f"Frontal LF detection failed for {ch_name}: {e}", detail="debug")
        frontal_lf_idx = list(set(frontal_lf_idx))
        ica.exclude.extend(frontal_lf_idx)

        # --- Line Noise (Improved: Sharp Peak Detection) ---
        self._log("Detecting line noise (58–62 Hz) with sharp peak criteria...", detail="debug")
        try:
            sfreq = raw.info['sfreq']
            src_data = ica.get_sources(raw_filtered).get_data()
            for i in range(ica.n_components_):
                if i in ica.exclude:
                    continue
                psd, freqs = mne.time_frequency.psd_array_welch(
                    src_data[i], sfreq=sfreq, fmin=1, fmax=100, verbose=False
                )
                line_band = (freqs >= 58) & (freqs <= 62)
                ref_band = (freqs >= 1) & (freqs <= 100)
                flank_band = ((freqs >= 50) & (freqs < 58)) | ((freqs > 62) & (freqs <= 70))

                if psd[ref_band].mean() == 0:
                    continue

                line_ratio = psd[line_band].mean() / psd[ref_band].mean()
                peak_in_line = psd[line_band].max()
                nearby_avg = psd[flank_band].mean()
                if nearby_avg == 0:
                    continue
                peak_prominence = peak_in_line / nearby_avg

                if line_ratio > 0.8 and peak_prominence > 5.0:
                    line_noise_idx.append(i)
                    self._log(f"  C{i} → line noise (ratio: {line_ratio:.2f}, prominence: {peak_prominence:.1f})", detail="debug")
            ica.exclude.extend(line_noise_idx)
            self._log(f"Line noise components: {sorted(line_noise_idx)}", detail="debug")
        except Exception as e:
            self._log(f"Line noise detection failed: {e}", detail="debug")

        # --- ICLabel: High-Confidence Artifact Detection ---
        self._log("Running mne-icalabel...", detail="debug")
        results['icalabel_excluded'] = []
        results['icalabel_confidences'] = {}
        results['icalabel_labels'] = {}  # Now stores labels
        try:
            labels_dict = label_components(raw_filtered, ica, method="iclabel")
            labels = labels_dict["labels"]
            probas = labels_dict["y_pred_proba"]
            CONFIDENCE_THRESHOLDS = {
                'eye blink': 0.85,
                'heart beat': 0.90,
                'muscle artifact': 0.80,
                'line noise': 0.90,
                'channel noise': 0.90
            }

            detected = []
            for i, (label, prob) in enumerate(zip(labels, probas)):
                lbl = label.lower().strip()
                if lbl in CONFIDENCE_THRESHOLDS and prob > CONFIDENCE_THRESHOLDS[lbl]:
                    detected.append((i, lbl, prob))
            new_excluded = [i for i, _, _ in detected if i not in ica.exclude]
            ica.exclude.extend(new_excluded)
            results['icalabel_excluded'] = sorted(new_excluded)
            results['icalabel_confidences'] = {i: probas[i] for i in new_excluded}
            results['icalabel_labels'] = {i: labels[i] for i in new_excluded}

            # Console: show type and confidence
            if new_excluded:
                iclabel_strs = [
                    f"C{i}({labels[i]}: {probas[i].max():.2f})"
                    for i in sorted(new_excluded)
                ]
                self._log(f"ICLabel added {len(new_excluded)}: {', '.join(iclabel_strs)}", detail="normal")
            else:
                self._log("ICLabel: No components added", detail="normal")

        except Exception as e:
            self._log(f"❌ ICLabel failed: {e}", detail="normal")

        # --- Signal Metrics ---
        try:
            src_data = ica.get_sources(raw_filtered).get_data()
            extreme_excluded = []
            for i in range(ica.n_components_):
                if i in ica.exclude:
                    continue
                x = src_data[i]
                var = np.var(x)
                kurt = kurtosis(x)
                ptp = np.ptp(x)
                is_dead_flat = var < 1e-14
                is_pure_spikes = kurt > 10000
                is_saturated = ptp > 100000
                if is_dead_flat or is_pure_spikes or is_saturated:
                    ica.exclude.append(i)
                    extreme_excluded.append(i)
                    self._log(f"Excluded component {i} via signal metrics", detail="debug")
            self._log(f"Signal metrics excluded: {extreme_excluded}", detail="debug")
        except Exception as e:
            self._log(f"Signal metrics failed: {e}", detail="debug")

        # === Apply ICA ===
        self._log(f"Applying ICA, excluding {len(ica.exclude)} components", detail="debug")
        cleaned_data = ica.apply(eeg_data.copy())

        # === FINAL PROFESSIONAL SUMMARY ===
        self._log("\n" + "━" * 60)
        self._log("🧩 ICA ARTIFACT REJECTION SUMMARY")
        self._log("━" * 60)
        self._log(f"{'Total components':<18} {ica.n_components_}")
        self._log(f"{'Excluded':<18} {len(ica.exclude)}")
        self._log("")
        self._log(f"{'Blink':<18} {sorted(blink_idx)}")
        self._log(f"{'Horizontal eye':<18} {sorted(h_saccade_idx)}")
        self._log(f"{'ECG':<18} {sorted(ecg_idx)}")
        self._log(f"{'Muscle':<18} {sorted(muscle_idx)}")
        self._log(f"{'Frontal LF':<18} {sorted(frontal_lf_idx)}")  # Updated name
        self._log(f"{'Line noise':<18} {sorted(line_noise_idx)}")
        if results.get('icalabel_excluded'):
            conf_str = ", ".join([
                f"C{i}({results['icalabel_labels'][i]}: {results['icalabel_confidences'][i].max():.2f})"
                for i in sorted(results['icalabel_excluded'])
            ])
            self._log(f"{'ICLabel':<18} {conf_str}")
        else:
            self._log(f"{'ICLabel':<18} []")
        self._log(f"{'Signal metrics':<18} {sorted(extreme_excluded) if 'extreme_excluded' in locals() else []}")
        self._log("")
        self._log(f"🔧 Final exclude list: {sorted(ica.exclude)}")
        self._log("━" * 60)

        # === Save ICA Plots ===

        if ica.exclude:
            try:
                fig_components = ica.plot_components(cmap=cmap, show=False)
                # ✅ Handle single figure (when only 1 page)
                if not isinstance(fig_components, list):
                    fig_components = [fig_components]

                plots_saved = []
                for i, fig in enumerate(fig_components):
                    comp_fig_path = os.path.join(self.output_path, "plots", f"{self.subject}_ica_components_page{i}.png")
                    # ✅ fig is already a Figure — no need for .get_figure()
                    fig.savefig(comp_fig_path, dpi=150, bbox_inches='tight')
                    plt.close(fig)  # ← Close the figure directly
                    plots_saved.append(comp_fig_path)
                self._log(f"🖼️ Saved {len(plots_saved)} ICA component page(s)")
            except Exception as e:
                self._log(f"⚠️ Failed to save ICA plots: {e}")

        # === Return ICA Object ===
        ica_object = {
            'ica_model': ica,
            'original_data': eeg_data,
            'filtered_data': raw_filtered,
            'auto_excluded': ica.exclude.copy(),
            'detection_results': {
                'blink_indices': sorted(blink_idx),
                'horizontal_eye_movement_indices': sorted(h_saccade_idx),
                'ecg_indices': sorted(ecg_idx),
                'muscle_indices': sorted(muscle_idx),
                'frontal_lf_indices': sorted(frontal_lf_idx),  # Updated key
                'line_noise_components': sorted(line_noise_idx),
                'icalabel_excluded': sorted(results.get('icalabel_excluded', [])),
                'signal_metrics_excluded': sorted(extreme_excluded) if 'extreme_excluded' in locals() else []
            },
            'parameters': {
                'n_components': n_components,
                'random_state': random_state,
                'vertical_eog': f"{vveog_anode}-{vveog_cathode} (vVEOG)",
                'horizontal_eog': f"{heog_anode}-{heog_cathode} (BLINK_H)",
                'ecg_derivation': f"{ecg_anode}-{ecg_cathode}",
                'emg_channels': emg_chs
            }
        }
        return cleaned_data, ica_object

    def run_ica_cleaning(self):
        self._log("Running automatic ICA cleaning...")
        cleaned, ica_obj = self.run_automatic_ica_cleaning(
            self.raw_cropped,
            n_components=0.99,
            random_state=self.random_state,
            cmap='viridis'
        )
        self.cleaned_data = cleaned
        self.ica_obj = ica_obj

    def plot_psd_comparison(self):
        """Plot and save PSD comparison before vs after ICA."""
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10), sharex=True)
        
        self.raw_cropped.compute_psd(fmax=120, picks='eeg', exclude='bads').plot(axes=ax1, show=False)
        ax1.set_title('Before ICA', fontsize=12)
        ax1.set_xlabel('')
        
        self.cleaned_data.compute_psd(fmax=120, picks='eeg', exclude='bads').plot(axes=ax2, show=False)
        ax2.set_title('After ICA', fontsize=12)
        
        fig.suptitle('Power Spectral Density: Before vs. After ICA', fontsize=16)
        
        # Avoid tight_layout warning
        plt.subplots_adjust(top=0.94, hspace=0.3)

        fig_path = os.path.join(self.output_path, "plots", f"{self.subject}_psd_comparison.png")
        fig.savefig(fig_path, dpi=150, bbox_inches='tight')
        self._log(f"📊 PSD comparison saved to: {fig_path}")
        plt.close(fig)

    def save_data(self):
        sub_id = self.subject.split('-')[1]
        fname = f"sub-{sub_id}_ses-{self.session}_task-{self.task}_eeg_ica_cleaned_raw.fif"
        full_path = os.path.join(self.output_path, fname)
        self.cleaned_data.save(full_path, overwrite=True)
        self._log(f"Cleaned data saved to: {full_path}")

    def run(self):
        self._log("🔄 Starting preprocessing...")
        
        # Step 1: Load and apply montage
        self.load_and_montage()
        self._log("✅ Loaded and montaged")
        
        # Step 2: Filter data (1–100 Hz + notch)
        self.filter_data()
        self._log("✅ Filtered data")
        
        # Step 3: Trim to task period and align events
        self.trim_events()
        self._log("✅ Trimmed events")
        
        # Step 4: Detect bad channels using MAD
        self.detect_bad_channels()
        self._log("✅ Detected bad channels")
        
        # 🔁 Step 5: Apply CAR *before* interpolation (CORRECT ORDER)
        self._log("🔧 Applying Common Average Reference (CAR) using only good channels...")
        self.raw_cropped = self.raw_cropped.set_eeg_reference('average', verbose=False)
        self._log("✅ Referenced (CAR applied)")

        # 🛠️ Step 6: Interpolate bad channels *after* referencing
        bads = self.raw_cropped.info['bads']
        if len(bads) > 0:
            self._log(f"🔧 Interpolating bad channels after CAR: {bads}")
            self.raw_cropped.interpolate_bads(reset_bads=True)
            self._log("✅ Bad channels interpolated")
        else:
            self._log("✅ No bad channels to interpolate")


        # Step 7: Run ICA cleaning (Picard recommended)
        self._log("🔧 Running ICA cleaning...")
        self.run_ica_cleaning()
        self._log("✅ ICA cleaning done")
        
        # Step 8: Save PSD comparison for QC
        self.plot_psd_comparison()
        self._log("✅ PSD comparison saved")
        
        # Step 9: Save cleaned data
        self.save_data()
        self._log("✅ Cleaned data saved")
        
        # Final message
        self._log("✅ FULL PREPROCESSING COMPLETE\n")

# %%
# REST HAND/FOOT BATCH PROCESSING LOOP (EYES CLOSED REST PERIOD OFF)
# =============================================================================
if __name__ == "__main__":
    import re
    import os

    # 📁 PATHS
    base_data = '/home/jaizor/jaizor/xtra/data/PD_Rest/OFF'  # ← REST data folder
    base_output = '/home/jaizor/jaizor/xtra/derivatives/clean'
    gpsc_file = '/home/jaizor/jaizor/xtra/data/ghw280_from_egig.gpsc'
    events_base = '/home/jaizor/jaizor/xtra/data/Events'

    # 👥 AUTO-DETECT SUBJECTS FROM FILENAMES
    def get_subjects_from_data_folder(data_dir: str, pattern: str = r"PD_(\d{3})_rest_hand_foot_DBSOFF\.mff") -> List[str]:
        subjects = []
        pattern = re.compile(pattern)
        for fname in os.listdir(data_dir):
            match = pattern.match(fname)
            if match:
                subj_num = int(match.group(1))
                subjects.append(f"sub-{subj_num:02d}")
        return sorted(subjects, key=lambda x: int(x.split('-')[1]))

    subjects = get_subjects_from_data_folder(base_data)
    print(f"📁 Found {len(subjects)} subjects: {subjects}")

    # ⚙️ TASK CONFIG
    session = 'DBSOFF'
    task = 'rest_hand_foot'  # ← Task name for output folder
    project_id_prefix = 'Sbj'
    plot_qc = False
    trigger_pairs = ('c', '3a')  # ✅ EYES CLOSED (c) → FOOT TASK START (3a) = REST PERIOD
    error_log_path = os.path.join(base_output, "processing_errors.txt")

    success_count = 0
    failure_count = 0

    # 🔄 PROCESS EACH SUBJECT
    for sub in tqdm(subjects, desc="EEG Rest Preprocessing (Eyes Closed)", unit="subject"):
        try:
            subj_num = int(sub[4:])  # e.g., 'sub-01' → 1
            mff_filename = f"PD_{subj_num:03d}_{task}_{session}.mff"
            mff_path = os.path.join(base_data, mff_filename)

            if not os.path.exists(mff_path):
                raise FileNotFoundError(f"MFF file not found: {mff_path}")

            processor = EEGICAProcessor(
                subject=sub,
                session=session,
                task=task,
                mff_path=mff_path,
                gpsc_file=gpsc_file,
                events_base=events_base,
                project_id=f"{project_id_prefix}{subj_num}",
                base_output_path=base_output,
                trigger_pairs=trigger_pairs,  # ✅ ('c', '3a') for rest period
                plot=plot_qc,
                random_state=99,
                log_to_file=True
            )
            processor.run()
            tqdm.write(f"✅ SUCCESS: {sub}")
            success_count += 1
        except Exception as e:
            error_msg = f"{sub}: {str(e)}\n{traceback.format_exc()}\n{'-'*60}\n"
            tqdm.write(f"❌ FAILED: {sub} — {e}")
            with open(error_log_path, 'a') as f:
                f.write(error_msg)
            failure_count += 1

        # Update progress bar postfix
        if hasattr(tqdm, '_instances'):
            for instance in list(tqdm._instances):
                instance.set_postfix(SUCCESS=success_count, FAILED=failure_count)

    print(f"\n✅ Processing Complete: {success_count} Success, {failure_count} Failures")
# Out:
# 📁 Found 12 subjects: ['sub-01', 'sub-02', 'sub-03', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-12', 'sub-14']
# EEG Rest Preprocessing (Eyes Closed):   0%|          | 0/12 [00:00<?, ?subject/s]
# Initialized EEGICAProcessor for sub-01/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 132.838s
# ✅ 3a: 2 onsets | Last: 689.804s
#
# ✂️ Trimming data to: 130.838s → 691.804s (560.97s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/rest_hand_foot_DBSOFF/sub-01_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj1_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E87', 'E129', 'E175', 'E218']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E87', 'E129', 'E175', 'E218']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 7: C7(heart beat: 0.94), C8(heart beat: 0.98), C36(heart beat: 0.92), C42(heart beat: 1.00), C60(heart beat: 0.98), C79(heart beat: 0.98), C82(heart beat: 0.96)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   102
# Excluded           22
#
# Blink              [13, 15, 97]
# Horizontal eye     [38, 73, 99]
# ECG                [43, 44, 57]
# Muscle             [10, 34, 66, 87]
# Frontal LF         [14]
# Line noise         []
# ICLabel            C7(heart beat: 0.94), C8(heart beat: 0.98), C36(heart beat: 0.92), C42(heart beat: 1.00), C60(heart beat: 0.98), C79(heart beat: 0.98), C82(heart beat: 0.96)
# Signal metrics     [65]
#
# 🔧 Final exclude list: [7, 8, 10, 13, 14, 15, 34, 36, 38, 42, 43, 44, 57, 60, 65, 66, 73, 79, 82, 87, 97, 99]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 6 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/rest_hand_foot_DBSOFF/plots/sub-01_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):   8%|▊         | 1/12 [04:39<51:09, 279.01s/subject, FAILED=0, SUCCESS=1]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/rest_hand_foot_DBSOFF/sub-01_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-01
# Initialized EEGICAProcessor for sub-02/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 61.072s
# ✅ 3a: 2 onsets | Last: 620.600s
#
# ✂️ Trimming data to: 59.072s → 622.600s (563.53s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/rest_hand_foot_DBSOFF/sub-02_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj2_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 18: C9(muscle artifact: 0.83), C14(muscle artifact: 0.98), C19(muscle artifact: 0.98), C20(muscle artifact: 0.99), C26(muscle artifact: 0.89), C41(channel noise: 0.99), C44(muscle artifact: 0.97), C47(muscle artifact: 0.84), C49(channel noise: 0.91), C52(muscle artifact: 0.81), C57(muscle artifact: 0.83), C58(muscle artifact: 0.99), C60(channel noise: 0.99), C65(muscle artifact: 1.00), C89(channel noise: 0.98), C99(channel noise: 0.97), C107(channel noise: 0.93), C119(channel noise: 0.95)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   120
# Excluded           36
#
# Blink              [0, 5, 30, 66]
# Horizontal eye     [1, 3, 7, 16, 54, 56]
# ECG                [1, 6, 7, 8]
# Muscle             [28, 50, 71, 88]
# Frontal LF         []
# Line noise         []
# ICLabel            C9(muscle artifact: 0.83), C14(muscle artifact: 0.98), C19(muscle artifact: 0.98), C20(muscle artifact: 0.99), C26(muscle artifact: 0.89), C41(channel noise: 0.99), C44(muscle artifact: 0.97), C47(muscle artifact: 0.84), C49(channel noise: 0.91), C52(muscle artifact: 0.81), C57(muscle artifact: 0.83), C58(muscle artifact: 0.99), C60(channel noise: 0.99), C65(muscle artifact: 1.00), C89(channel noise: 0.98), C99(channel noise: 0.97), C107(channel noise: 0.93), C119(channel noise: 0.95)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 1, 3, 5, 6, 7, 7, 8, 9, 14, 16, 19, 20, 26, 28, 30, 41, 44, 47, 49, 50, 52, 54, 56, 57, 58, 60, 65, 66, 71, 88, 89, 99, 107, 119]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 6 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/rest_hand_foot_DBSOFF/plots/sub-02_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  17%|█▋        | 2/12 [09:26<47:18, 283.88s/subject, FAILED=0, SUCCESS=2]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/rest_hand_foot_DBSOFF/sub-02_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-02
# Initialized EEGICAProcessor for sub-03/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 63.476s
# ✅ 3a: 2 onsets | Last: 600.532s
#
# ✂️ Trimming data to: 61.476s → 602.532s (541.06s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/rest_hand_foot_DBSOFF/sub-03_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj3_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E46', 'E48', 'E85', 'E87', 'E94', 'E138', 'E139', 'E160', 'E226', 'E242']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E46', 'E48', 'E85', 'E87', 'E94', 'E138', 'E139', 'E160', 'E226', 'E242']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 2: C1(channel noise: 0.94), C8(channel noise: 0.98)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   15
# Excluded           4
#
# Blink              [5]
# Horizontal eye     [6]
# ECG                []
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C1(channel noise: 0.94), C8(channel noise: 0.98)
# Signal metrics     []
#
# 🔧 Final exclude list: [1, 5, 6, 8]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 1 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/rest_hand_foot_DBSOFF/plots/sub-03_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  25%|██▌       | 3/12 [10:22<27:00, 180.05s/subject, FAILED=0, SUCCESS=3]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/rest_hand_foot_DBSOFF/sub-03_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-03
# Initialized EEGICAProcessor for sub-05/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 35.568s
# ✅ 3a: 2 onsets | Last: 505.146s
#
# ✂️ Trimming data to: 33.568s → 507.146s (473.58s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/rest_hand_foot_DBSOFF/sub-05_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj5_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 15: C14(channel noise: 0.92), C23(muscle artifact: 1.00), C29(channel noise: 0.90), C31(muscle artifact: 0.93), C38(muscle artifact: 1.00), C41(muscle artifact: 0.97), C49(muscle artifact: 0.92), C52(muscle artifact: 0.97), C60(muscle artifact: 0.97), C75(channel noise: 0.97), C77(muscle artifact: 0.92), C92(muscle artifact: 1.00), C96(muscle artifact: 0.91), C99(channel noise: 0.92), C100(muscle artifact: 0.87)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   110
# Excluded           30
#
# Blink              [0, 30, 59]
# Horizontal eye     [5, 12, 42]
# ECG                [3, 9, 74, 105]
# Muscle             [13, 26, 51, 68, 70]
# Frontal LF         []
# Line noise         []
# ICLabel            C14(channel noise: 0.92), C23(muscle artifact: 1.00), C29(channel noise: 0.90), C31(muscle artifact: 0.93), C38(muscle artifact: 1.00), C41(muscle artifact: 0.97), C49(muscle artifact: 0.92), C52(muscle artifact: 0.97), C60(muscle artifact: 0.97), C75(channel noise: 0.97), C77(muscle artifact: 0.92), C92(muscle artifact: 1.00), C96(muscle artifact: 0.91), C99(channel noise: 0.92), C100(muscle artifact: 0.87)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 3, 5, 9, 12, 13, 14, 23, 26, 29, 30, 31, 38, 41, 42, 49, 51, 52, 59, 60, 68, 70, 74, 75, 77, 92, 96, 99, 100, 105]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 6 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/rest_hand_foot_DBSOFF/plots/sub-05_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  33%|███▎      | 4/12 [14:31<27:38, 207.27s/subject, FAILED=0, SUCCESS=4]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/rest_hand_foot_DBSOFF/sub-05_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-05
# Initialized EEGICAProcessor for sub-06/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 68.120s
# ✅ 3a: 2 onsets | Last: 538.932s
#
# ✂️ Trimming data to: 66.120s → 540.932s (474.81s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/rest_hand_foot_DBSOFF/sub-06_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj6_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E32', 'E241']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E32', 'E241']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 5: C3(channel noise: 0.99), C20(muscle artifact: 0.90), C25(channel noise: 0.98), C39(channel noise: 0.99), C46(channel noise: 0.97)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   47
# Excluded           12
#
# Blink              [13, 21]
# Horizontal eye     [34]
# ECG                []
# Muscle             [32, 37, 41]
# Frontal LF         [5]
# Line noise         []
# ICLabel            C3(channel noise: 0.99), C20(muscle artifact: 0.90), C25(channel noise: 0.98), C39(channel noise: 0.99), C46(channel noise: 0.97)
# Signal metrics     []
#
# 🔧 Final exclude list: [3, 5, 13, 20, 21, 25, 32, 34, 37, 39, 41, 46]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 3 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/rest_hand_foot_DBSOFF/plots/sub-06_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  42%|████▏     | 5/12 [16:59<21:41, 185.97s/subject, FAILED=0, SUCCESS=5]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/rest_hand_foot_DBSOFF/sub-06_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-06
# Initialized EEGICAProcessor for sub-07/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 31.770s
# ✅ 3a: 2 onsets | Last: 498.444s
#
# ✂️ Trimming data to: 29.770s → 500.444s (470.67s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/rest_hand_foot_DBSOFF/sub-07_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj7_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E54', 'E101', 'E141', 'E231', 'E241', 'E267']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E54', 'E101', 'E141', 'E231', 'E241', 'E267']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 13: C8(muscle artifact: 0.80), C12(muscle artifact: 0.99), C17(muscle artifact: 0.99), C27(muscle artifact: 0.92), C28(muscle artifact: 0.99), C31(muscle artifact: 0.89), C35(muscle artifact: 0.98), C36(muscle artifact: 0.99), C39(muscle artifact: 0.93), C43(muscle artifact: 0.83), C47(muscle artifact: 0.84), C49(channel noise: 0.95), C51(channel noise: 0.99)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   52
# Excluded           20
#
# Blink              [21]
# Horizontal eye     [15]
# ECG                [20, 33]
# Muscle             [5, 6]
# Frontal LF         [9]
# Line noise         []
# ICLabel            C8(muscle artifact: 0.80), C12(muscle artifact: 0.99), C17(muscle artifact: 0.99), C27(muscle artifact: 0.92), C28(muscle artifact: 0.99), C31(muscle artifact: 0.89), C35(muscle artifact: 0.98), C36(muscle artifact: 0.99), C39(muscle artifact: 0.93), C43(muscle artifact: 0.83), C47(muscle artifact: 0.84), C49(channel noise: 0.95), C51(channel noise: 0.99)
# Signal metrics     []
#
# 🔧 Final exclude list: [5, 6, 8, 9, 12, 15, 17, 20, 21, 27, 28, 31, 33, 35, 36, 39, 43, 47, 49, 51]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 3 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/rest_hand_foot_DBSOFF/plots/sub-07_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  50%|█████     | 6/12 [19:07<16:35, 165.97s/subject, FAILED=0, SUCCESS=6]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/rest_hand_foot_DBSOFF/sub-07_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-07
# Initialized EEGICAProcessor for sub-08/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 130.650s
# ✅ 3a: 2 onsets | Last: 634.954s
#
# ✂️ Trimming data to: 128.650s → 636.954s (508.30s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/rest_hand_foot_DBSOFF/sub-08_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj8_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E48', 'E55', 'E88', 'E90', 'E91', 'E92', 'E98', 'E100', 'E103', 'E113', 'E114', 'E115', 'E123', 'E124', 'E136', 'E139', 'E140', 'E142', 'E148', 'E149', 'E150', 'E152', 'E153', 'E154', 'E161', 'E162', 'E165', 'E206', 'E216', 'E217', 'E223', 'E224', 'E225', 'E231', 'E234', 'E235', 'E241']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E48', 'E55', 'E88', 'E90', 'E91', 'E92', 'E98', 'E100', 'E103', 'E113', 'E114', 'E115', 'E123', 'E124', 'E136', 'E139', 'E140', 'E142', 'E148', 'E149', 'E150', 'E152', 'E153', 'E154', 'E161', 'E162', 'E165', 'E206', 'E216', 'E217', 'E223', 'E224', 'E225', 'E231', 'E234', 'E235', 'E241']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 2: C6(channel noise: 0.98), C7(channel noise: 0.92)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   9
# Excluded           2
#
# Blink              []
# Horizontal eye     []
# ECG                []
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C6(channel noise: 0.98), C7(channel noise: 0.92)
# Signal metrics     []
#
# 🔧 Final exclude list: [6, 7]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 1 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/rest_hand_foot_DBSOFF/plots/sub-08_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  58%|█████▊    | 7/12 [21:11<12:41, 152.23s/subject, FAILED=0, SUCCESS=7]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/rest_hand_foot_DBSOFF/sub-08_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-08
# Initialized EEGICAProcessor for sub-09/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 48.686s
# ✅ 3a: 2 onsets | Last: 528.070s
#
# ✂️ Trimming data to: 46.686s → 530.070s (483.38s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/rest_hand_foot_DBSOFF/sub-09_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj9_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 18: C4(channel noise: 0.93), C14(channel noise: 1.00), C20(channel noise: 0.96), C22(muscle artifact: 0.98), C23(muscle artifact: 0.96), C30(channel noise: 0.93), C40(muscle artifact: 0.99), C47(muscle artifact: 0.99), C49(channel noise: 0.94), C55(muscle artifact: 0.89), C62(muscle artifact: 0.98), C66(muscle artifact: 1.00), C73(channel noise: 0.91), C77(muscle artifact: 0.95), C79(muscle artifact: 1.00), C85(muscle artifact: 1.00), C87(muscle artifact: 1.00), C88(muscle artifact: 0.95)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   89
# Excluded           30
#
# Blink              [0, 2]
# Horizontal eye     [5, 29]
# ECG                [11, 12, 24]
# Muscle             [18, 28, 48, 56, 58]
# Frontal LF         []
# Line noise         []
# ICLabel            C4(channel noise: 0.93), C14(channel noise: 1.00), C20(channel noise: 0.96), C22(muscle artifact: 0.98), C23(muscle artifact: 0.96), C30(channel noise: 0.93), C40(muscle artifact: 0.99), C47(muscle artifact: 0.99), C49(channel noise: 0.94), C55(muscle artifact: 0.89), C62(muscle artifact: 0.98), C66(muscle artifact: 1.00), C73(channel noise: 0.91), C77(muscle artifact: 0.95), C79(muscle artifact: 1.00), C85(muscle artifact: 1.00), C87(muscle artifact: 1.00), C88(muscle artifact: 0.95)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 2, 4, 5, 11, 12, 14, 18, 20, 22, 23, 24, 28, 29, 30, 40, 47, 48, 49, 55, 56, 58, 62, 66, 73, 77, 79, 85, 87, 88]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 5 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/rest_hand_foot_DBSOFF/plots/sub-09_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  67%|██████▋   | 8/12 [24:32<11:11, 167.87s/subject, FAILED=0, SUCCESS=8]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/rest_hand_foot_DBSOFF/sub-09_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-09
# Initialized EEGICAProcessor for sub-10/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 29.628s
# ✅ 3a: 2 onsets | Last: 507.646s
#
# ✂️ Trimming data to: 27.628s → 509.646s (482.02s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSOFF/sub-10_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 170
#    After trimming:  170
#    Duration: 27.63s → 509.65s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSOFF/sub-10_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSOFF/sub-10_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E48', 'E87', 'E88']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E48', 'E87', 'E88']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 7: C6(heart beat: 0.97), C10(channel noise: 0.93), C18(muscle artifact: 0.92), C40(muscle artifact: 0.96), C46(muscle artifact: 0.85), C51(muscle artifact: 0.96), C60(muscle artifact: 0.90)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   68
# Excluded           18
#
# Blink              [4, 26]
# Horizontal eye     [3, 8, 57]
# ECG                [0, 2, 14]
# Muscle             [19, 22]
# Frontal LF         [1]
# Line noise         []
# ICLabel            C6(heart beat: 0.97), C10(channel noise: 0.93), C18(muscle artifact: 0.92), C40(muscle artifact: 0.96), C46(muscle artifact: 0.85), C51(muscle artifact: 0.96), C60(muscle artifact: 0.90)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 4, 6, 8, 10, 14, 18, 19, 22, 26, 40, 46, 51, 57, 60]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 4 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSOFF/plots/sub-10_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  75%|███████▌  | 9/12 [27:09<08:13, 164.44s/subject, FAILED=0, SUCCESS=9]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSOFF/sub-10_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-10
# Initialized EEGICAProcessor for sub-11/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 40.668s
# ✅ 3a: 2 onsets | Last: 511.860s
#
# ✂️ Trimming data to: 38.668s → 513.860s (475.19s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/rest_hand_foot_DBSOFF/sub-11_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 570
#    After trimming:  505
#    Duration: 38.67s → 513.86s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/rest_hand_foot_DBSOFF/sub-11_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/rest_hand_foot_DBSOFF/sub-11_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E46', 'E53', 'E86', 'E87', 'E94', 'E98', 'E139', 'E228', 'E229']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E46', 'E53', 'E86', 'E87', 'E94', 'E98', 'E139', 'E228', 'E229']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 6: C0(channel noise: 0.98), C3(channel noise: 0.97), C10(channel noise: 0.94), C11(channel noise: 0.99), C12(channel noise: 0.95), C14(channel noise: 0.90)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   16
# Excluded           9
#
# Blink              []
# Horizontal eye     [13]
# ECG                [1, 2]
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C0(channel noise: 0.98), C3(channel noise: 0.97), C10(channel noise: 0.94), C11(channel noise: 0.99), C12(channel noise: 0.95), C14(channel noise: 0.90)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 10, 11, 12, 13, 14]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 1 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/rest_hand_foot_DBSOFF/plots/sub-11_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  83%|████████▎ | 10/12 [27:51<04:13, 126.63s/subject, FAILED=0, SUCCESS=10]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/rest_hand_foot_DBSOFF/sub-11_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-11
# Initialized EEGICAProcessor for sub-12/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a', 'TT140']
# 🔍 Starting event-based trimming...
# ✅ c: 2 onsets | First: 44.728s
# ✅ 3a: 4 onsets | Last: 616.358s
#
# ✂️ Trimming data to: 42.728s → 618.358s (575.63s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSOFF/sub-12_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a', 'TT140']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 272
#    After trimming:  272
#    Duration: 42.73s → 618.36s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSOFF/sub-12_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSOFF/sub-12_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E114', 'E124', 'E233']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E114', 'E124', 'E233']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 8: C5(channel noise: 0.94), C6(channel noise: 0.98), C31(muscle artifact: 0.85), C34(muscle artifact: 0.87), C39(muscle artifact: 0.91), C40(channel noise: 0.98), C73(muscle artifact: 0.83), C92(channel noise: 0.98)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   94
# Excluded           25
#
# Blink              [12, 14, 20, 41]
# Horizontal eye     [9, 15, 52, 67, 77]
# ECG                [10, 82]
# Muscle             [51, 54, 57, 79, 83]
# Frontal LF         [7]
# Line noise         []
# ICLabel            C5(channel noise: 0.94), C6(channel noise: 0.98), C31(muscle artifact: 0.85), C34(muscle artifact: 0.87), C39(muscle artifact: 0.91), C40(channel noise: 0.98), C73(muscle artifact: 0.83), C92(channel noise: 0.98)
# Signal metrics     []
#
# 🔧 Final exclude list: [5, 6, 7, 9, 10, 12, 14, 15, 20, 31, 34, 39, 40, 41, 51, 52, 54, 57, 67, 73, 77, 79, 82, 83, 92]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 5 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSOFF/plots/sub-12_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  92%|█████████▏| 11/12 [31:22<02:32, 152.65s/subject, FAILED=0, SUCCESS=11]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSOFF/sub-12_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-12
# Initialized EEGICAProcessor for sub-14/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 118.694s
# ✅ 3a: 2 onsets | Last: 645.320s
#
# ✂️ Trimming data to: 116.694s → 647.320s (530.63s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/rest_hand_foot_DBSOFF/sub-14_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 108
#    After trimming:  106
#    Duration: 116.69s → 647.32s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/rest_hand_foot_DBSOFF/sub-14_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/rest_hand_foot_DBSOFF/sub-14_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E271']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E271']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 7: C15(muscle artifact: 0.83), C22(muscle artifact: 0.81), C24(channel noise: 0.91), C37(channel noise: 0.99), C53(channel noise: 0.99), C54(channel noise: 0.92), C70(channel noise: 0.98)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   71
# Excluded           20
#
# Blink              [2, 44, 50, 65]
# Horizontal eye     [12, 26, 28]
# ECG                [9, 17]
# Muscle             [8, 19, 42]
# Frontal LF         [3]
# Line noise         []
# ICLabel            C15(muscle artifact: 0.83), C22(muscle artifact: 0.81), C24(channel noise: 0.91), C37(channel noise: 0.99), C53(channel noise: 0.99), C54(channel noise: 0.92), C70(channel noise: 0.98)
# Signal metrics     []
#
# 🔧 Final exclude list: [2, 3, 8, 9, 12, 15, 17, 19, 22, 24, 26, 28, 37, 42, 44, 50, 53, 54, 65, 70]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 4 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/rest_hand_foot_DBSOFF/plots/sub-14_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed): 100%|██████████| 12/12 [34:11<00:00, 170.94s/subject, FAILED=0, SUCCESS=12]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/rest_hand_foot_DBSOFF/sub-14_ses-DBSOFF_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-14
#
# ✅ Processing Complete: 12 Success, 0 Failures

# %%
# BIMA BATCH PROCESSING LOOP
# =============================================================================
if __name__ == "__main__":
    base_data = '/home/jaizor/jaizor/xtra/data/PD_Bima'
    base_output = '/home/jaizor/jaizor/xtra/derivatives/clean'
    gpsc_file = '/home/jaizor/jaizor/xtra/data/ghw280_from_egig.gpsc'
    events_base = '/home/jaizor/jaizor/xtra/data/Events'


    subjects = ['sub-01', 'sub-02', 'sub-03', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-12', 'sub-14']

    session = 'DBSOFF'
    task = 'bima'
    project_id_prefix = 'Sbj'
    plot_qc = False  
    trigger_pairs = ('1a', '6a')
    error_log_path = os.path.join(base_output, "processing_errors.txt")

    success_count = 0
    failure_count = 0

    for sub in tqdm(subjects, desc="ParallelGroup EEG Processing", unit="subject"):
        try:
            subj_num = sub[4:]
            mff_path = f'{base_data}/PD_{subj_num.zfill(3)}_bima_DBSOFF.mff'

            if not os.path.exists(mff_path):
                raise FileNotFoundError(f"MFF file not found: {mff_path}")

            processor = EEGICAProcessor(
                subject=sub,
                session=session,
                task=task,
                mff_path=mff_path,
                gpsc_file=gpsc_file,
                events_base=events_base,
                project_id=f"{project_id_prefix}{subj_num}",
                base_output_path=base_output,
                trigger_pairs=trigger_pairs,
                plot=plot_qc,
                random_state=99,
                log_to_file=True
            )
            processor.run()
            tqdm.write(f"✅ SUCCESS: {sub}")
            success_count += 1
        except Exception as e:
            error_msg = f"{sub}: {str(e)}\n{traceback.format_exc()}\n{'-'*60}\n"
            tqdm.write(f"❌ FAILED: {sub} — {e}")
            with open(error_log_path, 'a') as f:
                f.write(error_msg)
            failure_count += 1

        if hasattr(tqdm, '_instances'):
            for instance in list(tqdm._instances):
                instance.set_postfix(SUCCESS=success_count, FAILED=failure_count)

    print(f"\n✅ Processing Complete: {success_count} Success, {failure_count} Failures")
# Out:
# ParallelGroup EEG Processing:   0%|          | 0/12 [00:00<?, ?subject/s]
# Initialized EEGICAProcessor for sub-01/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 252.418s
# ✅ 6a: 200 onsets | Last: 679.362s
#
# ✂️ Trimming data to: 250.418s → 681.362s (430.94s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/bima_DBSOFF/sub-01_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 585
#    After trimming:  578
#    Duration: 250.42s → 681.36s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/bima_DBSOFF/sub-01_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/bima_DBSOFF/sub-01_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E83', 'E87', 'E111', 'E124', 'E129', 'E145', 'E175', 'E176', 'E218']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E83', 'E87', 'E111', 'E124', 'E129', 'E145', 'E175', 'E176', 'E218']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 8: C2(heart beat: 1.00), C7(heart beat: 0.97), C11(heart beat: 0.90), C15(heart beat: 0.95), C24(muscle artifact: 0.98), C52(heart beat: 0.95), C56(channel noise: 0.95), C99(channel noise: 0.91)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   125
# Excluded           26
#
# Blink              [3, 9, 14, 63, 118, 121]
# Horizontal eye     [20, 23, 85, 106]
# ECG                [80]
# Muscle             [0, 5, 21, 29, 50, 66, 74]
# Frontal LF         []
# Line noise         []
# ICLabel            C2(heart beat: 1.00), C7(heart beat: 0.97), C11(heart beat: 0.90), C15(heart beat: 0.95), C24(muscle artifact: 0.98), C52(heart beat: 0.95), C56(channel noise: 0.95), C99(channel noise: 0.91)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 2, 3, 5, 7, 9, 11, 14, 15, 20, 21, 23, 24, 29, 50, 52, 56, 63, 66, 74, 80, 85, 99, 106, 118, 121]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 7 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/bima_DBSOFF/plots/sub-01_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:   8%|▊         | 1/12 [05:28<1:00:14, 328.60s/subject, FAILED=0, SUCCESS=1]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/bima_DBSOFF/sub-01_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-01
# Initialized EEGICAProcessor for sub-02/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 117.290s
# ✅ 6a: 200 onsets | Last: 610.220s
#
# ✂️ Trimming data to: 115.290s → 612.220s (496.93s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/bima_DBSOFF/sub-02_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 292
#    After trimming:  288
#    Duration: 115.29s → 612.22s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/bima_DBSOFF/sub-02_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/bima_DBSOFF/sub-02_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E228']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E228']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 37: C1(channel noise: 0.91), C6(muscle artifact: 0.88), C14(heart beat: 0.90), C22(muscle artifact: 0.86), C26(muscle artifact: 0.97), C31(muscle artifact: 1.00), C35(muscle artifact: 0.99), C36(channel noise: 0.91), C37(muscle artifact: 0.97), C38(channel noise: 0.91), C41(channel noise: 0.98), C42(muscle artifact: 0.93), C44(muscle artifact: 1.00), C51(channel noise: 0.99), C53(muscle artifact: 0.93), C58(muscle artifact: 1.00), C61(muscle artifact: 0.85), C62(muscle artifact: 0.95), C63(channel noise: 0.99), C64(channel noise: 0.93), C67(muscle artifact: 0.84), C68(channel noise: 0.96), C72(muscle artifact: 0.91), C75(muscle artifact: 0.91), C80(muscle artifact: 0.89), C81(muscle artifact: 0.91), C83(channel noise: 0.98), C85(channel noise: 0.98), C86(channel noise: 0.93), C98(muscle artifact: 0.94), C99(channel noise: 0.99), C108(channel noise: 0.94), C111(channel noise: 0.99), C112(channel noise: 0.97), C121(channel noise: 0.96), C131(channel noise: 0.95), C133(channel noise: 0.99)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   145
# Excluded           58
#
# Blink              [0, 11, 20, 43, 52, 54]
# Horizontal eye     [8, 19, 76]
# ECG                [2, 3, 4, 9, 10, 15, 89]
# Muscle             [17, 39, 55, 117, 132]
# Frontal LF         []
# Line noise         []
# ICLabel            C1(channel noise: 0.91), C6(muscle artifact: 0.88), C14(heart beat: 0.90), C22(muscle artifact: 0.86), C26(muscle artifact: 0.97), C31(muscle artifact: 1.00), C35(muscle artifact: 0.99), C36(channel noise: 0.91), C37(muscle artifact: 0.97), C38(channel noise: 0.91), C41(channel noise: 0.98), C42(muscle artifact: 0.93), C44(muscle artifact: 1.00), C51(channel noise: 0.99), C53(muscle artifact: 0.93), C58(muscle artifact: 1.00), C61(muscle artifact: 0.85), C62(muscle artifact: 0.95), C63(channel noise: 0.99), C64(channel noise: 0.93), C67(muscle artifact: 0.84), C68(channel noise: 0.96), C72(muscle artifact: 0.91), C75(muscle artifact: 0.91), C80(muscle artifact: 0.89), C81(muscle artifact: 0.91), C83(channel noise: 0.98), C85(channel noise: 0.98), C86(channel noise: 0.93), C98(muscle artifact: 0.94), C99(channel noise: 0.99), C108(channel noise: 0.94), C111(channel noise: 0.99), C112(channel noise: 0.97), C121(channel noise: 0.96), C131(channel noise: 0.95), C133(channel noise: 0.99)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 4, 6, 8, 9, 10, 11, 14, 15, 17, 19, 20, 22, 26, 31, 35, 36, 37, 38, 39, 41, 42, 43, 44, 51, 52, 53, 54, 55, 58, 61, 62, 63, 64, 67, 68, 72, 75, 76, 80, 81, 83, 85, 86, 89, 98, 99, 108, 111, 112, 117, 121, 131, 132, 133]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 8 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/bima_DBSOFF/plots/sub-02_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  17%|█▋        | 2/12 [11:35<58:31, 351.17s/subject, FAILED=0, SUCCESS=2]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/bima_DBSOFF/sub-02_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-02
# Initialized EEGICAProcessor for sub-03/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 116.236s
# ✅ 6a: 200 onsets | Last: 618.380s
#
# ✂️ Trimming data to: 114.236s → 620.380s (506.14s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/bima_DBSOFF/sub-03_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 702
#    After trimming:  645
#    Duration: 114.24s → 620.38s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/bima_DBSOFF/sub-03_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/bima_DBSOFF/sub-03_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E46', 'E48', 'E49', 'E53', 'E54', 'E85', 'E86', 'E87', 'E94', 'E138', 'E160', 'E226', 'E231', 'E242', 'E270']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E46', 'E48', 'E49', 'E53', 'E54', 'E85', 'E86', 'E87', 'E94', 'E138', 'E160', 'E226', 'E231', 'E242', 'E270']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 2: C19(channel noise: 0.94), C20(muscle artifact: 0.90)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   26
# Excluded           9
#
# Blink              [6, 11]
# Horizontal eye     [10]
# ECG                [0, 3]
# Muscle             [14, 16]
# Frontal LF         []
# Line noise         []
# ICLabel            C19(channel noise: 0.94), C20(muscle artifact: 0.90)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 3, 6, 10, 11, 14, 16, 19, 20]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 2 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/bima_DBSOFF/plots/sub-03_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  25%|██▌       | 3/12 [12:21<31:48, 212.02s/subject, FAILED=0, SUCCESS=3]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/bima_DBSOFF/sub-03_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-03
# Initialized EEGICAProcessor for sub-05/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a', 'TT185']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 15.882s
# ✅ 6a: 200 onsets | Last: 538.914s
#
# ✂️ Trimming data to: 13.882s → 540.914s (527.03s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/bima_DBSOFF/sub-05_cropping_info.json
# ✅ Preserved stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a', 'TT185']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 265
#    After trimming:  265
#    Duration: 13.88s → 540.91s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/bima_DBSOFF/sub-05_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/bima_DBSOFF/sub-05_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 24: C12(muscle artifact: 1.00), C26(muscle artifact: 0.98), C27(muscle artifact: 0.94), C36(muscle artifact: 1.00), C37(muscle artifact: 0.93), C44(muscle artifact: 0.98), C45(muscle artifact: 0.99), C46(muscle artifact: 0.98), C49(muscle artifact: 0.93), C50(muscle artifact: 0.96), C52(muscle artifact: 1.00), C54(muscle artifact: 0.94), C55(muscle artifact: 1.00), C61(muscle artifact: 1.00), C63(muscle artifact: 0.99), C67(muscle artifact: 0.96), C69(muscle artifact: 0.99), C71(muscle artifact: 1.00), C73(channel noise: 0.96), C75(muscle artifact: 0.98), C77(muscle artifact: 1.00), C79(muscle artifact: 0.99), C80(channel noise: 0.97), C81(muscle artifact: 0.88)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   82
# Excluded           39
#
# Blink              [1, 31, 74]
# Horizontal eye     [47]
# ECG                [15, 22]
# Muscle             [0, 3, 10, 35, 38, 40, 43, 57]
# Frontal LF         []
# Line noise         [65]
# ICLabel            C12(muscle artifact: 1.00), C26(muscle artifact: 0.98), C27(muscle artifact: 0.94), C36(muscle artifact: 1.00), C37(muscle artifact: 0.93), C44(muscle artifact: 0.98), C45(muscle artifact: 0.99), C46(muscle artifact: 0.98), C49(muscle artifact: 0.93), C50(muscle artifact: 0.96), C52(muscle artifact: 1.00), C54(muscle artifact: 0.94), C55(muscle artifact: 1.00), C61(muscle artifact: 1.00), C63(muscle artifact: 0.99), C67(muscle artifact: 0.96), C69(muscle artifact: 0.99), C71(muscle artifact: 1.00), C73(channel noise: 0.96), C75(muscle artifact: 0.98), C77(muscle artifact: 1.00), C79(muscle artifact: 0.99), C80(channel noise: 0.97), C81(muscle artifact: 0.88)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 3, 10, 12, 15, 22, 26, 27, 31, 35, 36, 37, 38, 40, 43, 44, 45, 46, 47, 49, 50, 52, 54, 55, 57, 61, 63, 65, 67, 69, 71, 73, 74, 75, 77, 79, 80, 81]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 5 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/bima_DBSOFF/plots/sub-05_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  33%|███▎      | 4/12 [15:08<25:50, 193.86s/subject, FAILED=0, SUCCESS=4]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/bima_DBSOFF/sub-05_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-05
# Initialized EEGICAProcessor for sub-06/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 46.094s
# ✅ 6a: 200 onsets | Last: 569.138s
#
# ✂️ Trimming data to: 44.094s → 571.138s (527.04s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/bima_DBSOFF/sub-06_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 363
#    After trimming:  363
#    Duration: 44.09s → 571.14s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/bima_DBSOFF/sub-06_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/bima_DBSOFF/sub-06_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E18', 'E32', 'E88', 'E280']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E18', 'E32', 'E88', 'E280']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 7: C2(channel noise: 0.97), C11(channel noise: 0.94), C23(channel noise: 0.92), C24(channel noise: 0.93), C34(channel noise: 0.95), C66(channel noise: 0.96), C94(muscle artifact: 0.87)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   102
# Excluded           24
#
# Blink              [12, 36, 68, 70]
# Horizontal eye     [54, 64, 88]
# ECG                [46, 86]
# Muscle             [8, 37, 40, 44, 48, 82]
# Frontal LF         [10, 15]
# Line noise         []
# ICLabel            C2(channel noise: 0.97), C11(channel noise: 0.94), C23(channel noise: 0.92), C24(channel noise: 0.93), C34(channel noise: 0.95), C66(channel noise: 0.96), C94(muscle artifact: 0.87)
# Signal metrics     []
#
# 🔧 Final exclude list: [2, 8, 10, 11, 12, 15, 23, 24, 34, 36, 37, 40, 44, 46, 48, 54, 64, 66, 68, 70, 82, 86, 88, 94]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 6 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/bima_DBSOFF/plots/sub-06_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  42%|████▏     | 5/12 [19:08<24:34, 210.58s/subject, FAILED=0, SUCCESS=5]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/bima_DBSOFF/sub-06_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-06
# Initialized EEGICAProcessor for sub-07/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 35.862s
# ✅ 6a: 200 onsets | Last: 558.890s
#
# ✂️ Trimming data to: 33.862s → 560.890s (527.03s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/bima_DBSOFF/sub-07_cropping_info.json
# ✅ Preserved stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 479
#    After trimming:  476
#    Duration: 33.86s → 560.89s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/bima_DBSOFF/sub-07_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/bima_DBSOFF/sub-07_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E54', 'E101', 'E141', 'E233', 'E241', 'E267']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E54', 'E101', 'E141', 'E233', 'E241', 'E267']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 34: C9(muscle artifact: 1.00), C14(muscle artifact: 1.00), C15(muscle artifact: 1.00), C18(muscle artifact: 0.83), C23(muscle artifact: 1.00), C30(muscle artifact: 1.00), C34(channel noise: 0.99), C35(muscle artifact: 1.00), C36(muscle artifact: 0.96), C37(muscle artifact: 0.98), C40(muscle artifact: 0.99), C42(muscle artifact: 1.00), C44(muscle artifact: 0.99), C45(muscle artifact: 0.99), C49(channel noise: 0.91), C52(muscle artifact: 0.91), C53(muscle artifact: 1.00), C54(muscle artifact: 0.99), C56(muscle artifact: 0.99), C60(muscle artifact: 0.91), C63(muscle artifact: 0.99), C64(muscle artifact: 0.93), C69(muscle artifact: 0.93), C70(muscle artifact: 0.98), C75(muscle artifact: 0.98), C83(muscle artifact: 1.00), C84(muscle artifact: 0.95), C85(muscle artifact: 0.97), C88(muscle artifact: 0.99), C90(muscle artifact: 1.00), C92(muscle artifact: 0.97), C100(muscle artifact: 0.98), C103(muscle artifact: 0.92), C108(muscle artifact: 0.99)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   109
# Excluded           52
#
# Blink              [12, 26, 48, 72, 95]
# Horizontal eye     [58]
# ECG                [4, 5, 20, 22]
# Muscle             [0, 1, 2, 3, 67, 76, 86, 102]
# Frontal LF         []
# Line noise         []
# ICLabel            C9(muscle artifact: 1.00), C14(muscle artifact: 1.00), C15(muscle artifact: 1.00), C18(muscle artifact: 0.83), C23(muscle artifact: 1.00), C30(muscle artifact: 1.00), C34(channel noise: 0.99), C35(muscle artifact: 1.00), C36(muscle artifact: 0.96), C37(muscle artifact: 0.98), C40(muscle artifact: 0.99), C42(muscle artifact: 1.00), C44(muscle artifact: 0.99), C45(muscle artifact: 0.99), C49(channel noise: 0.91), C52(muscle artifact: 0.91), C53(muscle artifact: 1.00), C54(muscle artifact: 0.99), C56(muscle artifact: 0.99), C60(muscle artifact: 0.91), C63(muscle artifact: 0.99), C64(muscle artifact: 0.93), C69(muscle artifact: 0.93), C70(muscle artifact: 0.98), C75(muscle artifact: 0.98), C83(muscle artifact: 1.00), C84(muscle artifact: 0.95), C85(muscle artifact: 0.97), C88(muscle artifact: 0.99), C90(muscle artifact: 1.00), C92(muscle artifact: 0.97), C100(muscle artifact: 0.98), C103(muscle artifact: 0.92), C108(muscle artifact: 0.99)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 4, 5, 9, 12, 14, 15, 18, 20, 22, 23, 26, 30, 34, 35, 36, 37, 40, 42, 44, 45, 48, 49, 52, 53, 54, 56, 58, 60, 63, 64, 67, 69, 70, 72, 75, 76, 83, 84, 85, 86, 88, 90, 92, 95, 100, 102, 103, 108]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 6 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/bima_DBSOFF/plots/sub-07_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  50%|█████     | 6/12 [22:37<20:59, 209.99s/subject, FAILED=0, SUCCESS=6]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/bima_DBSOFF/sub-07_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-07
# Initialized EEGICAProcessor for sub-08/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 176.160s
# ✅ 6a: 200 onsets | Last: 699.120s
#
# ✂️ Trimming data to: 174.160s → 701.120s (526.96s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/bima_DBSOFF/sub-08_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 77
#    After trimming:  75
#    Duration: 174.16s → 701.12s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/bima_DBSOFF/sub-08_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/bima_DBSOFF/sub-08_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E48', 'E55', 'E74', 'E88', 'E90', 'E91', 'E92', 'E98', 'E100', 'E103', 'E113', 'E114', 'E115', 'E123', 'E124', 'E125', 'E126', 'E135', 'E136', 'E139', 'E140', 'E141', 'E142', 'E143', 'E148', 'E149', 'E150', 'E151', 'E152', 'E153', 'E154', 'E161', 'E162', 'E163', 'E165', 'E206', 'E215', 'E216', 'E217', 'E222', 'E223', 'E224', 'E225', 'E228', 'E229', 'E231', 'E234', 'E235', 'E241']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E48', 'E55', 'E74', 'E88', 'E90', 'E91', 'E92', 'E98', 'E100', 'E103', 'E113', 'E114', 'E115', 'E123', 'E124', 'E125', 'E126', 'E135', 'E136', 'E139', 'E140', 'E141', 'E142', 'E143', 'E148', 'E149', 'E150', 'E151', 'E152', 'E153', 'E154', 'E161', 'E162', 'E163', 'E165', 'E206', 'E215', 'E216', 'E217', 'E222', 'E223', 'E224', 'E225', 'E228', 'E229', 'E231', 'E234', 'E235', 'E241']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel: No components added
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   5
# Excluded           0
#
# Blink              []
# Horizontal eye     []
# ECG                []
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            []
# Signal metrics     []
#
# 🔧 Final exclude list: []
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/bima_DBSOFF/plots/sub-08_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  58%|█████▊    | 7/12 [24:27<14:46, 177.32s/subject, FAILED=0, SUCCESS=7]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-08/bima_DBSOFF/sub-08_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-08
# Initialized EEGICAProcessor for sub-09/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 45.390s
# ✅ 6a: 200 onsets | Last: 568.400s
#
# ✂️ Trimming data to: 43.390s → 570.400s (527.01s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/bima_DBSOFF/sub-09_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 393
#    After trimming:  393
#    Duration: 43.39s → 570.40s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/bima_DBSOFF/sub-09_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/bima_DBSOFF/sub-09_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 1: C40(line noise: 0.92)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   48
# Excluded           10
#
# Blink              [2, 45]
# Horizontal eye     [13, 19]
# ECG                [21, 38]
# Muscle             [31, 47]
# Frontal LF         [1]
# Line noise         []
# ICLabel            C40(line noise: 0.92)
# Signal metrics     []
#
# 🔧 Final exclude list: [1, 2, 13, 19, 21, 31, 38, 40, 45, 47]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 3 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/bima_DBSOFF/plots/sub-09_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  67%|██████▋   | 8/12 [26:25<10:34, 158.59s/subject, FAILED=0, SUCCESS=8]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/bima_DBSOFF/sub-09_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-09
# Initialized EEGICAProcessor for sub-10/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 62.100s
# ✅ 6a: 200 onsets | Last: 585.146s
#
# ✂️ Trimming data to: 60.100s → 587.146s (527.05s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/bima_DBSOFF/sub-10_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', '1a', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 170
#    After trimming:  170
#    Duration: 60.10s → 587.15s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/bima_DBSOFF/sub-10_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/bima_DBSOFF/sub-10_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E48', 'E87', 'E88', 'E229']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E48', 'E87', 'E88', 'E229']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 21: C2(channel noise: 1.00), C14(channel noise: 0.90), C16(muscle artifact: 1.00), C19(muscle artifact: 0.99), C26(muscle artifact: 0.94), C29(channel noise: 0.96), C35(muscle artifact: 0.99), C37(muscle artifact: 0.99), C39(muscle artifact: 0.88), C40(muscle artifact: 0.98), C43(muscle artifact: 1.00), C44(muscle artifact: 0.97), C48(muscle artifact: 1.00), C53(muscle artifact: 0.95), C54(muscle artifact: 0.98), C57(muscle artifact: 0.94), C62(muscle artifact: 1.00), C63(muscle artifact: 0.82), C64(muscle artifact: 0.95), C65(muscle artifact: 1.00), C70(muscle artifact: 0.98)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   73
# Excluded           37
#
# Blink              [0, 49]
# Horizontal eye     [1, 3, 52]
# ECG                [5, 21, 41]
# Muscle             [6, 13, 15, 17, 34, 58]
# Frontal LF         [4, 10]
# Line noise         []
# ICLabel            C2(channel noise: 1.00), C14(channel noise: 0.90), C16(muscle artifact: 1.00), C19(muscle artifact: 0.99), C26(muscle artifact: 0.94), C29(channel noise: 0.96), C35(muscle artifact: 0.99), C37(muscle artifact: 0.99), C39(muscle artifact: 0.88), C40(muscle artifact: 0.98), C43(muscle artifact: 1.00), C44(muscle artifact: 0.97), C48(muscle artifact: 1.00), C53(muscle artifact: 0.95), C54(muscle artifact: 0.98), C57(muscle artifact: 0.94), C62(muscle artifact: 1.00), C63(muscle artifact: 0.82), C64(muscle artifact: 0.95), C65(muscle artifact: 1.00), C70(muscle artifact: 0.98)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 4, 5, 6, 10, 13, 14, 15, 16, 17, 19, 21, 26, 29, 34, 35, 37, 39, 40, 41, 43, 44, 48, 49, 52, 53, 54, 57, 58, 62, 63, 64, 65, 70]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 4 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/bima_DBSOFF/plots/sub-10_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  75%|███████▌  | 9/12 [28:58<07:50, 156.87s/subject, FAILED=0, SUCCESS=9]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/bima_DBSOFF/sub-10_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-10
# Initialized EEGICAProcessor for sub-11/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 32.116s
# ✅ 6a: 200 onsets | Last: 554.828s
#
# ✂️ Trimming data to: 30.116s → 556.828s (526.71s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/bima_DBSOFF/sub-11_cropping_info.json
# ✅ Preserved stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 570
#    After trimming:  570
#    Duration: 30.12s → 556.83s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/bima_DBSOFF/sub-11_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/bima_DBSOFF/sub-11_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E53', 'E86', 'E148', 'E159', 'E228', 'E229', 'E230']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E53', 'E86', 'E148', 'E159', 'E228', 'E229', 'E230']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 6: C0(channel noise: 0.97), C2(channel noise: 0.91), C4(channel noise: 0.91), C8(channel noise: 0.91), C22(channel noise: 0.99), C27(channel noise: 0.95)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   31
# Excluded           12
#
# Blink              [5, 16]
# Horizontal eye     []
# ECG                [1, 9]
# Muscle             [14, 30]
# Frontal LF         []
# Line noise         []
# ICLabel            C0(channel noise: 0.97), C2(channel noise: 0.91), C4(channel noise: 0.91), C8(channel noise: 0.91), C22(channel noise: 0.99), C27(channel noise: 0.95)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 4, 5, 8, 9, 14, 16, 22, 27, 30]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 2 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/bima_DBSOFF/plots/sub-11_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  83%|████████▎ | 10/12 [29:55<04:11, 125.87s/subject, FAILED=0, SUCCESS=10]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-11/bima_DBSOFF/sub-11_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-11
# Initialized EEGICAProcessor for sub-12/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 180 onsets | First: 67.734s
# ✅ 6a: 160 onsets | Last: 485.044s
#
# ✂️ Trimming data to: 65.734s → 487.044s (421.31s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/bima_DBSOFF/sub-12_cropping_info.json
# ✅ Preserved stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 272
#    After trimming:  272
#    Duration: 65.73s → 487.04s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/bima_DBSOFF/sub-12_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/bima_DBSOFF/sub-12_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E215', 'E221', 'E223', 'E229', 'E233']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E215', 'E221', 'E223', 'E229', 'E233']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 2: C15(channel noise: 0.98), C18(channel noise: 0.95)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   27
# Excluded           3
#
# Blink              []
# Horizontal eye     [26]
# ECG                []
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C15(channel noise: 0.98), C18(channel noise: 0.95)
# Signal metrics     []
#
# 🔧 Final exclude list: [15, 18, 26]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 2 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/bima_DBSOFF/plots/sub-12_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing:  92%|█████████▏| 11/12 [31:35<01:58, 118.03s/subject, FAILED=0, SUCCESS=11]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/bima_DBSOFF/sub-12_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-12
# Initialized EEGICAProcessor for sub-14/DBSOFF
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
# 🔍 Starting event-based trimming...
# ✅ 1a: 200 onsets | First: 124.126s
# ✅ 6a: 200 onsets | Last: 646.836s
#
# ✂️ Trimming data to: 122.126s → 648.836s (526.71s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/bima_DBSOFF/sub-14_cropping_info.json
# ✅ Preserved stim channels: ['1a', 'TT255', '2a', '3a', '4a', '5a', '6a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 108
#    After trimming:  108
#    Duration: 122.13s → 648.84s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/bima_DBSOFF/sub-14_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/bima_DBSOFF/sub-14_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E230', 'E240', 'E271']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E230', 'E240', 'E271']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 29: C8(channel noise: 0.99), C12(muscle artifact: 0.85), C22(muscle artifact: 0.97), C24(heart beat: 0.90), C28(muscle artifact: 0.99), C31(muscle artifact: 0.82), C34(muscle artifact: 0.92), C35(heart beat: 0.94), C38(muscle artifact: 0.83), C42(channel noise: 0.93), C44(muscle artifact: 0.83), C49(channel noise: 0.99), C50(muscle artifact: 0.97), C55(channel noise: 0.99), C58(muscle artifact: 1.00), C65(muscle artifact: 0.89), C67(channel noise: 0.95), C68(muscle artifact: 1.00), C69(muscle artifact: 0.94), C78(channel noise: 0.99), C82(channel noise: 0.97), C92(channel noise: 0.96), C94(muscle artifact: 0.97), C96(muscle artifact: 0.96), C101(muscle artifact: 0.83), C105(channel noise: 0.95), C115(channel noise: 0.99), C116(channel noise: 1.00), C117(channel noise: 0.97)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   118
# Excluded           44
#
# Blink              [1, 36, 52, 73]
# Horizontal eye     [17, 29, 47]
# ECG                [5, 14, 72, 91]
# Muscle             [6, 7, 40, 56]
# Frontal LF         []
# Line noise         []
# ICLabel            C8(channel noise: 0.99), C12(muscle artifact: 0.85), C22(muscle artifact: 0.97), C24(heart beat: 0.90), C28(muscle artifact: 0.99), C31(muscle artifact: 0.82), C34(muscle artifact: 0.92), C35(heart beat: 0.94), C38(muscle artifact: 0.83), C42(channel noise: 0.93), C44(muscle artifact: 0.83), C49(channel noise: 0.99), C50(muscle artifact: 0.97), C55(channel noise: 0.99), C58(muscle artifact: 1.00), C65(muscle artifact: 0.89), C67(channel noise: 0.95), C68(muscle artifact: 1.00), C69(muscle artifact: 0.94), C78(channel noise: 0.99), C82(channel noise: 0.97), C92(channel noise: 0.96), C94(muscle artifact: 0.97), C96(muscle artifact: 0.96), C101(muscle artifact: 0.83), C105(channel noise: 0.95), C115(channel noise: 0.99), C116(channel noise: 1.00), C117(channel noise: 0.97)
# Signal metrics     []
#
# 🔧 Final exclude list: [1, 5, 6, 7, 8, 12, 14, 17, 22, 24, 28, 29, 31, 34, 35, 36, 38, 40, 42, 44, 47, 49, 50, 52, 55, 56, 58, 65, 67, 68, 69, 72, 73, 78, 82, 91, 92, 94, 96, 101, 105, 115, 116, 117]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 6 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/bima_DBSOFF/plots/sub-14_psd_comparison.png
# ✅ PSD comparison saved
# ParallelGroup EEG Processing: 100%|██████████| 12/12 [35:13<00:00, 176.12s/subject, FAILED=0, SUCCESS=12]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-14/bima_DBSOFF/sub-14_ses-DBSOFF_task-bima_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-14
#
# ✅ Processing Complete: 12 Success, 0 Failures

# %%
# REST HAND/FOOT BATCH PROCESSING LOOP (EYES CLOSED REST PERIOD ON)
# =============================================================================
if __name__ == "__main__":
    import re
    import os

    # 📁 PATHS
    base_data = '/home/jaizor/jaizor/xtra/data/PD_Rest/ON'  # ← REST data folder
    base_output = '/home/jaizor/jaizor/xtra/derivatives/clean'
    gpsc_file = '/home/jaizor/jaizor/xtra/data/ghw280_from_egig.gpsc'
    events_base = '/home/jaizor/jaizor/xtra/data/Events'

    # 👥 AUTO-DETECT SUBJECTS FROM FILENAMES
    def get_subjects_from_data_folder(data_dir: str, pattern: str = r"PD_(\d{3})_rest_hand_foot_DBSON\.mff") -> List[str]:
        subjects = []
        pattern = re.compile(pattern)
        for fname in os.listdir(data_dir):
            match = pattern.match(fname)
            if match:
                subj_num = int(match.group(1))
                subjects.append(f"sub-{subj_num:02d}")
        return sorted(subjects, key=lambda x: int(x.split('-')[1]))

    subjects = get_subjects_from_data_folder(base_data)
    print(f"📁 Found {len(subjects)} subjects: {subjects}")

    # ⚙️ TASK CONFIG
    session = 'DBSON'
    task = 'rest_hand_foot'  # ← Task name for output folder
    project_id_prefix = 'Sbj'
    plot_qc = False
    trigger_pairs = ('c', '3a')  # ✅ EYES CLOSED (c) → FOOT TASK START (3a) = REST PERIOD
    error_log_path = os.path.join(base_output, "processing_errors.txt")

    success_count = 0
    failure_count = 0

    # 🔄 PROCESS EACH SUBJECT
    for sub in tqdm(subjects, desc="EEG Rest Preprocessing (Eyes Closed)", unit="subject"):
        try:
            subj_num = int(sub[4:])  # e.g., 'sub-01' → 1
            mff_filename = f"PD_{subj_num:03d}_{task}_{session}.mff"
            mff_path = os.path.join(base_data, mff_filename)

            if not os.path.exists(mff_path):
                raise FileNotFoundError(f"MFF file not found: {mff_path}")

            processor = EEGICAProcessor(
                subject=sub,
                session=session,
                task=task,
                mff_path=mff_path,
                gpsc_file=gpsc_file,
                events_base=events_base,
                project_id=f"{project_id_prefix}{subj_num}",
                base_output_path=base_output,
                trigger_pairs=trigger_pairs,  # ✅ ('c', '3a') for rest period
                plot=plot_qc,
                random_state=99,
                log_to_file=True
            )
            processor.run()
            tqdm.write(f"✅ SUCCESS: {sub}")
            success_count += 1
        except Exception as e:
            error_msg = f"{sub}: {str(e)}\n{traceback.format_exc()}\n{'-'*60}\n"
            tqdm.write(f"❌ FAILED: {sub} — {e}")
            with open(error_log_path, 'a') as f:
                f.write(error_msg)
            failure_count += 1

        # Update progress bar postfix
        if hasattr(tqdm, '_instances'):
            for instance in list(tqdm._instances):
                instance.set_postfix(SUCCESS=success_count, FAILED=failure_count)

    print(f"\n✅ Processing Complete: {success_count} Success, {failure_count} Failures")
# Out:
# 📁 Found 10 subjects: ['sub-01', 'sub-02', 'sub-03', 'sub-05', 'sub-06', 'sub-07', 'sub-09', 'sub-10', 'sub-12', 'sub-14']
# EEG Rest Preprocessing (Eyes Closed):   0%|          | 0/10 [00:00<?, ?subject/s]
# Initialized EEGICAProcessor for sub-01/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 392.660s
# ✅ 3a: 2 onsets | Last: 967.362s
#
# ✂️ Trimming data to: 390.660s → 969.362s (578.70s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/rest_hand_foot_DBSON/sub-01_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj1_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E87']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E87']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 3: C1(channel noise: 0.94), C6(channel noise: 0.97), C92(muscle artifact: 0.98)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   97
# Excluded           17
#
# Blink              [3, 79, 81, 95]
# Horizontal eye     [5, 7, 26]
# ECG                [38, 46]
# Muscle             [19, 43, 44, 51, 67]
# Frontal LF         []
# Line noise         []
# ICLabel            C1(channel noise: 0.94), C6(channel noise: 0.97), C92(muscle artifact: 0.98)
# Signal metrics     []
#
# 🔧 Final exclude list: [1, 3, 5, 6, 7, 19, 26, 38, 43, 44, 46, 51, 67, 79, 81, 92, 95]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 5 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/rest_hand_foot_DBSON/plots/sub-01_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  10%|█         | 1/10 [04:34<41:11, 274.59s/subject, FAILED=0, SUCCESS=1]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-01/rest_hand_foot_DBSON/sub-01_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-01
# Initialized EEGICAProcessor for sub-02/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 2 onsets | First: 247.960s
# ✅ 3a: 2 onsets | Last: 840.742s
#
# ✂️ Trimming data to: 245.960s → 842.742s (596.78s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/rest_hand_foot_DBSON/sub-02_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj2_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E32', 'E228']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E32', 'E228']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 21: C36(muscle artifact: 0.99), C53(muscle artifact: 1.00), C54(muscle artifact: 1.00), C58(channel noise: 0.91), C68(channel noise: 0.97), C69(muscle artifact: 0.94), C74(channel noise: 0.99), C78(muscle artifact: 0.94), C91(muscle artifact: 0.95), C92(muscle artifact: 0.99), C96(channel noise: 0.92), C97(muscle artifact: 0.89), C102(channel noise: 0.97), C103(muscle artifact: 0.89), C106(muscle artifact: 1.00), C108(channel noise: 0.91), C122(channel noise: 1.00), C124(channel noise: 0.95), C133(channel noise: 0.99), C136(channel noise: 0.96), C142(channel noise: 0.95)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   150
# Excluded           43
#
# Blink              [0, 1, 3, 16, 18, 21, 22, 23]
# Horizontal eye     [6, 11, 17, 38, 45, 73, 93]
# ECG                [2, 12, 20, 41]
# Muscle             [14, 40, 44]
# Frontal LF         []
# Line noise         []
# ICLabel            C36(muscle artifact: 0.99), C53(muscle artifact: 1.00), C54(muscle artifact: 1.00), C58(channel noise: 0.91), C68(channel noise: 0.97), C69(muscle artifact: 0.94), C74(channel noise: 0.99), C78(muscle artifact: 0.94), C91(muscle artifact: 0.95), C92(muscle artifact: 0.99), C96(channel noise: 0.92), C97(muscle artifact: 0.89), C102(channel noise: 0.97), C103(muscle artifact: 0.89), C106(muscle artifact: 1.00), C108(channel noise: 0.91), C122(channel noise: 1.00), C124(channel noise: 0.95), C133(channel noise: 0.99), C136(channel noise: 0.96), C142(channel noise: 0.95)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 6, 11, 12, 14, 16, 17, 18, 20, 21, 22, 23, 36, 38, 40, 41, 44, 45, 53, 54, 58, 68, 69, 73, 74, 78, 91, 92, 93, 96, 97, 102, 103, 106, 108, 122, 124, 133, 136, 142]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 8 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/rest_hand_foot_DBSON/plots/sub-02_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  20%|██        | 2/10 [10:19<42:05, 315.73s/subject, FAILED=0, SUCCESS=2]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-02/rest_hand_foot_DBSON/sub-02_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-02
# Initialized EEGICAProcessor for sub-03/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 86.416s
# ✅ 3a: 2 onsets | Last: 567.016s
#
# ✂️ Trimming data to: 84.416s → 569.016s (484.60s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/rest_hand_foot_DBSON/sub-03_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj3_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E46', 'E86', 'E87', 'E93', 'E138', 'E145', 'E146', 'E229', 'E231', 'E242']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E46', 'E86', 'E87', 'E93', 'E138', 'E145', 'E146', 'E229', 'E231', 'E242']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 1: C12(channel noise: 0.99)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   20
# Excluded           5
#
# Blink              [13]
# Horizontal eye     [14]
# ECG                [1, 15]
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C12(channel noise: 0.99)
# Signal metrics     []
#
# 🔧 Final exclude list: [1, 12, 13, 14, 15]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 1 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/rest_hand_foot_DBSON/plots/sub-03_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  30%|███       | 3/10 [11:02<22:19, 191.38s/subject, FAILED=0, SUCCESS=3]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-03/rest_hand_foot_DBSON/sub-03_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-03
# Initialized EEGICAProcessor for sub-05/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 31.184s
# ✅ 3a: 2 onsets | Last: 522.484s
#
# ✂️ Trimming data to: 29.184s → 524.484s (495.30s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/rest_hand_foot_DBSON/sub-05_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj5_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 12: C10(muscle artifact: 0.86), C12(muscle artifact: 0.85), C18(muscle artifact: 0.81), C23(muscle artifact: 0.82), C42(muscle artifact: 0.98), C45(muscle artifact: 0.99), C46(channel noise: 0.92), C47(muscle artifact: 1.00), C49(muscle artifact: 1.00), C50(muscle artifact: 0.95), C51(channel noise: 0.93), C53(muscle artifact: 0.97)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   54
# Excluded           20
#
# Blink              [2]
# Horizontal eye     [15, 16]
# ECG                [14, 36]
# Muscle             [26, 27, 33]
# Frontal LF         []
# Line noise         []
# ICLabel            C10(muscle artifact: 0.86), C12(muscle artifact: 0.85), C18(muscle artifact: 0.81), C23(muscle artifact: 0.82), C42(muscle artifact: 0.98), C45(muscle artifact: 0.99), C46(channel noise: 0.92), C47(muscle artifact: 1.00), C49(muscle artifact: 1.00), C50(muscle artifact: 0.95), C51(channel noise: 0.93), C53(muscle artifact: 0.97)
# Signal metrics     []
#
# 🔧 Final exclude list: [2, 10, 12, 14, 15, 16, 18, 23, 26, 27, 33, 36, 42, 45, 46, 47, 49, 50, 51, 53]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 3 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/rest_hand_foot_DBSON/plots/sub-05_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  40%|████      | 4/10 [13:26<17:16, 172.67s/subject, FAILED=0, SUCCESS=4]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-05/rest_hand_foot_DBSON/sub-05_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-05
# Initialized EEGICAProcessor for sub-06/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 60.532s
# ✅ 3a: 2 onsets | Last: 549.526s
#
# ✂️ Trimming data to: 58.532s → 551.526s (492.99s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/rest_hand_foot_DBSON/sub-06_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj6_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E32', 'E241']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E32', 'E241']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 8: C12(muscle artifact: 0.92), C24(muscle artifact: 0.96), C28(channel noise: 0.96), C30(muscle artifact: 0.89), C34(channel noise: 0.91), C44(channel noise: 0.95), C50(channel noise: 0.93), C63(muscle artifact: 0.88)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   71
# Excluded           23
#
# Blink              [10, 11, 32]
# Horizontal eye     [16, 38]
# ECG                [18, 35, 67]
# Muscle             [15, 17, 22, 29, 49]
# Frontal LF         [7]
# Line noise         []
# ICLabel            C12(muscle artifact: 0.92), C24(muscle artifact: 0.96), C28(channel noise: 0.96), C30(muscle artifact: 0.89), C34(channel noise: 0.91), C44(channel noise: 0.95), C50(channel noise: 0.93), C63(muscle artifact: 0.88)
# Signal metrics     [3]
#
# 🔧 Final exclude list: [3, 7, 10, 11, 12, 15, 16, 17, 18, 22, 24, 28, 29, 30, 32, 34, 35, 38, 44, 49, 50, 63, 67]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 4 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/rest_hand_foot_DBSON/plots/sub-06_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  50%|█████     | 5/10 [15:59<13:47, 165.48s/subject, FAILED=0, SUCCESS=5]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-06/rest_hand_foot_DBSON/sub-06_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-06
# Initialized EEGICAProcessor for sub-07/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 43.656s
# ✅ 3a: 2 onsets | Last: 564.648s
#
# ✂️ Trimming data to: 41.656s → 566.648s (524.99s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/rest_hand_foot_DBSON/sub-07_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj7_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E54', 'E55', 'E101', 'E223', 'E228', 'E230', 'E233', 'E241']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E54', 'E55', 'E101', 'E223', 'E228', 'E230', 'E233', 'E241']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 1: C1(channel noise: 0.98)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   6
# Excluded           1
#
# Blink              []
# Horizontal eye     []
# ECG                []
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C1(channel noise: 0.98)
# Signal metrics     []
#
# 🔧 Final exclude list: [1]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 1 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/rest_hand_foot_DBSON/plots/sub-07_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  60%|██████    | 6/10 [16:35<08:05, 121.49s/subject, FAILED=0, SUCCESS=6]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-07/rest_hand_foot_DBSON/sub-07_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-07
# Initialized EEGICAProcessor for sub-09/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 82.966s
# ✅ 3a: 2 onsets | Last: 548.012s
#
# ✂️ Trimming data to: 80.966s → 550.012s (469.05s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/rest_hand_foot_DBSON/sub-09_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# ⏭️ Skipping event alignment - missing file: /home/jaizor/jaizor/xtra/data/Events/Sbj9_events_mne_binary-eve.fif
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): []
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel: No components added
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   7
# Excluded           0
#
# Blink              []
# Horizontal eye     []
# ECG                []
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            []
# Signal metrics     []
#
# 🔧 Final exclude list: []
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/rest_hand_foot_DBSON/plots/sub-09_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  70%|███████   | 7/10 [18:11<05:39, 113.21s/subject, FAILED=0, SUCCESS=7]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-09/rest_hand_foot_DBSON/sub-09_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-09
# Initialized EEGICAProcessor for sub-10/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 42.374s
# ✅ 3a: 2 onsets | Last: 566.236s
#
# ✂️ Trimming data to: 40.374s → 568.236s (527.86s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSON/sub-10_cropping_info.json
# ✅ Preserved stim channels: ['TT140', 'TT255', 'c', 'x', 'o', '1a', '2a', '3a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 170
#    After trimming:  170
#    Duration: 40.37s → 568.24s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSON/sub-10_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSON/sub-10_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E48', 'E87', 'E88']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E48', 'E87', 'E88']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 8: C14(channel noise: 0.95), C17(channel noise: 0.91), C41(muscle artifact: 1.00), C42(channel noise: 0.96), C51(channel noise: 0.99), C56(muscle artifact: 0.91), C80(channel noise: 0.97), C88(muscle artifact: 0.90)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   93
# Excluded           24
#
# Blink              [1, 2, 13, 29]
# Horizontal eye     [3, 5, 45, 77]
# ECG                [0, 15, 21]
# Muscle             [6, 10, 12, 31, 86]
# Frontal LF         []
# Line noise         []
# ICLabel            C14(channel noise: 0.95), C17(channel noise: 0.91), C41(muscle artifact: 1.00), C42(channel noise: 0.96), C51(channel noise: 0.99), C56(muscle artifact: 0.91), C80(channel noise: 0.97), C88(muscle artifact: 0.90)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 1, 2, 3, 5, 6, 10, 12, 13, 14, 15, 17, 21, 29, 31, 41, 42, 45, 51, 56, 77, 80, 86, 88]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 5 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSON/plots/sub-10_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  80%|████████  | 8/10 [21:46<04:50, 145.46s/subject, FAILED=0, SUCCESS=8]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-10/rest_hand_foot_DBSON/sub-10_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-10
# Initialized EEGICAProcessor for sub-12/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
# 🔍 Starting event-based trimming...
# ✅ c: 1 onsets | First: 172.508s
# ✅ 3a: 2 onsets | Last: 657.616s
#
# ✂️ Trimming data to: 170.508s → 659.616s (489.11s)
# 📄 Cropping metadata saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSON/sub-12_cropping_info.json
# ✅ Preserved stim channels: ['c', 'TT255', 'x', 'o', '1a', '2a', '3a']
#
# ✅ EVENT ALIGNMENT COMPLETE
#    Original events: 272
#    After trimming:  221
#    Duration: 170.51s → 659.62s
#    Events saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSON/sub-12_events_mne_binary-eve.fif
#    Event ID saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSON/sub-12_event_id_binary.json
#    Event IDs: {'InPhase': 0, 'OutofPhase': 1}
# ✅ Trimming & event alignment complete.
# ✅ Trimmed events
# Detecting bad channels using MAD...
# Bad channels (MAD): ['E113', 'E221', 'E223', 'E233']
# ✅ Detected bad channels
# 🔧 Applying Common Average Reference (CAR) using only good channels...
# ✅ Referenced (CAR applied)
# 🔧 Interpolating bad channels after CAR: ['Cz', 'E113', 'E221', 'E223', 'E233']
# ✅ Bad channels interpolated
# 🔧 Running ICA cleaning...
# Running automatic ICA cleaning...
# ICLabel added 3: C2(channel noise: 0.92), C8(channel noise: 0.99), C13(channel noise: 0.95)
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🧩 ICA ARTIFACT REJECTION SUMMARY
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total components   25
# Excluded           6
#
# Blink              []
# Horizontal eye     [11]
# ECG                [0, 12]
# Muscle             []
# Frontal LF         []
# Line noise         []
# ICLabel            C2(channel noise: 0.92), C8(channel noise: 0.99), C13(channel noise: 0.95)
# Signal metrics     []
#
# 🔧 Final exclude list: [0, 2, 8, 11, 12, 13]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🖼️ Saved 2 ICA component page(s)
# ✅ ICA cleaning done
# 📊 PSD comparison saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSON/plots/sub-12_psd_comparison.png
# ✅ PSD comparison saved
# EEG Rest Preprocessing (Eyes Closed):  90%|█████████ | 9/10 [23:50<02:18, 138.99s/subject, FAILED=0, SUCCESS=9]
# Cleaned data saved to: /home/jaizor/jaizor/xtra/derivatives/clean/sub-12/rest_hand_foot_DBSON/sub-12_ses-DBSON_task-rest_hand_foot_eeg_ica_cleaned_raw.fif
# ✅ Cleaned data saved
# ✅ FULL PREPROCESSING COMPLETE
#
# ✅ SUCCESS: sub-12
# Initialized EEGICAProcessor for sub-14/DBSON
# 🔄 Starting preprocessing...
# Loading raw data from .mff...
# Parsing and applying montage from .gpsc...
# Original mean position (mm): [100.83802817  94.83802817 166.92605634]
# Montage applied.
# ✅ Loaded and montaged
# Applying bandpass (1–100 Hz) and notch (60 Hz harmonics) filters...
# EEG Rest Preprocessing (Eyes Closed): 100%|██████████| 10/10 [24:18<00:00, 145.84s/subject, FAILED=1, SUCCESS=9]
# Marked Cz as bad (flat signal).
# ✅ Filtered data
# Stim channels: []
# 🔍 Starting event-based trimming...
# ❌ FAILED: sub-14 — Trigger channels missing: []
#
# ✅ Processing Complete: 9 Success, 1 Failures
